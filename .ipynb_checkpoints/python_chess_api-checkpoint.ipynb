# %%
import asyncio
import requests

import pandas as pd
import numpy as np
import matplotlib as plt

import json
import re
from datetime import datetime

# %%
# emergency backup code
# wnny-uifa-zayo-sjxw-enwi

# %%
# Accessing Chess API data
# Access User Profile Data
# Access User's current and historical games
# Access for any chess game both players ids and the outcome/status of the game.

# %%
url_player_profile = "https://api.chess.com/pub/player/"

usr = "jokerrnikita"

resp = requests.get(url_player_profile + usr)

# %%
resp.status_code
# Out:
# 200

# %%
resp.json()
# Out:
# {'player_id': 55647830,
#  '@id': 'https://api.chess.com/pub/player/jokerrnikita',
#  'url': 'https://www.chess.com/member/JokerrNikita',
#  'name': 'Никита Иванов',
#  'username': 'jokerrnikita',
#  'followers': 2,
#  'country': 'https://api.chess.com/pub/country/GB',
#  'last_online': 1651003804,
#  'joined': 1546877782,
#  'status': 'basic',
#  'is_streamer': False}

# %%
# Check if inputted player exist. So that later we can bring all the games history played.
def isPlayerExist(username):
    try:
        url = f"https://api.chess.com/pub/player/{username}"
        response = requests.get(url)
        if response.status_code == 404:
            raise ValueError("Such username was not found")
    except ValueError as e:
        print(e)
        print(f"{str(response.status_code)} error. {response.reason}")
        # Return false if not found.
        return False
    else:
        return response.json()

# %%
data = isPlayerExist("jokerrniita")
# Out:
# Such username was not found
# 404 error. Not Found

# %%
data
# Out:
# False

# %%
username = "Hikaru"
url_latest_games_for_username = f" https://api.chess.com/pub/player/{username}/games/{year}/{month}"

try:
    resp = requests.get(url_latest_games_for_username)
    if resp.status_code == 404:
        raise ValueError("Such username was not found. Error 404")
except ValueError as e:
    print(e)

# %%
games_history = resp.json()

# %%
usr_games_history = games_history['games']

# %%
pat = "^(?:(?:31(\/|-|\.)(?:0?[13578]|1[02]|(?:Jan|Mar|May|Jul|Aug|Oct|Dec)))\1|(?:(?:29|30)(\/|-|\.)(?:0?[1,3-9]|1[0-2]|(?:Jan|Mar|Apr|May|Jun|Jul|Aug|Sep|Oct|Nov|Dec))\2))(?:(?:1[6-9]|[2-9]\d)?\d{2})$|^(?:29(\/|-|\.)(?:0?2|(?:Feb))\3(?:(?:(?:1[6-9]|[2-9]\d)?(?:0[48]|[2468][048]|[13579][26])|(?:(?:16|[2468][048]|[3579][26])00))))$|^(?:0?[1-9]|1\d|2[0-8])(\/|-|\.)(?:(?:0?[1-9]|(?:Jan|Feb|Mar|Apr|May|Jun|Jul|Aug|Sep))|(?:1[0-2]|(?:Oct|Nov|Dec)))\4(?:(?:1[6-9]|[2-9]\d)?\d{2})$"

# %%
txt_to_test = usr_games_history[0]['pgn']

# %%
txt_to_test
# Out:
# '[Event "Live Chess"]\n[Site "Chess.com"]\n[Date "2022.04.02"]\n[Round "-"]\n[White "HansOnTwitch"]\n[Black "Hikaru"]\n[Result "0-1"]\n[CurrentPosition "r4bk1/1p1n1p1p/p3p1p1/P2pP3/1n1P1P2/1Nr1B3/1P2N1PP/R5K1 w - -"]\n[Timezone "UTC"]\n[ECO "A40"]\n[ECOUrl "https://www.chess.com/openings/Modern-Defense-with-1-d4"]\n[UTCDate "2022.04.02"]\n[UTCTime "15:04:18"]\n[WhiteElo "3014"]\n[BlackElo "3215"]\n[TimeControl "180"]\n[Termination "Hikaru won by resignation"]\n[StartTime "15:04:18"]\n[EndDate "2022.04.02"]\n[EndTime "15:06:10"]\n[Link "https://www.chess.com/game/live/42650958287"]\n\n1. d4 {[%clk 0:03:00]} 1... g6 {[%clk 0:03:00]} 2. Nc3 {[%clk 0:02:55.2]} 2... Bg7 {[%clk 0:02:59.9]} 3. e4 {[%clk 0:02:53.2]} 3... a6 {[%clk 0:02:59.8]} 4. Nf3 {[%clk 0:02:48.6]} 4... d6 {[%clk 0:02:59.1]} 5. a4 {[%clk 0:02:45.4]} 5... Bg4 {[%clk 0:02:58.2]} 6. Be2 {[%clk 0:02:44.3]} 6... Nd7 {[%clk 0:02:56.1]} 7. O-O {[%clk 0:02:42.8]} 7... e6 {[%clk 0:02:49.4]} 8. Be3 {[%clk 0:02:39.5]} 8... Ne7 {[%clk 0:02:48.1]} 9. Nd2 {[%clk 0:02:37.3]} 9... Bxe2 {[%clk 0:02:46.9]} 10. Nxe2 {[%clk 0:02:37.2]} 10... O-O {[%clk 0:02:45.9]} 11. c3 {[%clk 0:02:33]} 11... c5 {[%clk 0:02:42.5]} 12. a5 {[%clk 0:02:31.1]} 12... cxd4 {[%clk 0:02:36.2]} 13. cxd4 {[%clk 0:02:31]} 13... Nc6 {[%clk 0:02:33.9]} 14. Qa4 {[%clk 0:02:29.3]} 14... d5 {[%clk 0:02:27.4]} 15. e5 {[%clk 0:02:25.3]} 15... Qe7 {[%clk 0:02:26.7]} 16. f4 {[%clk 0:02:23.5]} 16... Rfc8 {[%clk 0:02:24.3]} 17. Rfc1 {[%clk 0:02:22]} 17... Bf8 {[%clk 0:02:20.4]} 18. Nb3 {[%clk 0:02:18.6]} 18... Qb4 {[%clk 0:02:19.5]} 19. Qxb4 {[%clk 0:02:16.2]} 19... Nxb4 {[%clk 0:02:19.4]} 20. Rc3 {[%clk 0:02:10.7]} 20... Rxc3 {[%clk 0:02:16.7]} 0-1\n'

# %%
x = re.findall('\d{4}.\d{2}.\d{2}', txt_to_test)

# %%
x
# Out:
# ['2022.04.02', '2022.04.02', '2022.04.02', '4265095828']

# %%
x_time = re.findall('\d{2}:\d{2}.\d{2}', txt_to_test)
x_time
# Out:
# ['15:04:18', '15:04:18', '15:06:10']

# %%
current_date = datetime.now().date()
current_month = current_date.strftime("%m")
current_year = current_date.strftime("%Y")
# Out:
# '2022'

# %%
lost_status = ['abandoned', 'checkmated', 'resigned', 'lose', 'timeout']
draw_status = ['stalemate', 'repetition', 'agreed']
win_status = ['win']

# Storing the user's games and respective result won/lost for each game. Key 1, represents game 1 the user played.
def player_games_history(player_games_data, username, year, month):
    
    url_latest_games_for_username = f" https://api.chess.com/pub/player/{username}/games/{year}/{month}"
    
    try:
        response = requests.get(url_latest_games_for_username)
        if response.status_code == 404:
            raise ValueError("Such username was not found. Error 404")
    except ValueError as e:
        print(e)
        
    else:
        games_history = response.json()
        usr_games_history = games_history['games']
        
        # Creating a dictionary of player's games history
        for idx, game_dict in enumerate(usr_games_history):
            
            # grabbing date and time for when the game was played.
            txt_string = game_dict['pgn']
            
            date_game = re.findall('\d{4}.\d{2}.\d{2}', txt_string)[0]
            time_game = re.findall('\d{2}:\d{2}.\d{2}', txt_string)[-1]

            
            
            # grabbing each game dictionary/obj
            white_outcome = game_dict['white']['result']
            black_outcome = game_dict['black']['result']

            white_username = game_dict['white']['username']
            black_username = game_dict['black']['username']

            if white_username == username:
                player_games_data[idx + 1] = {white_username: white_outcome, black_username: black_outcome, "white": white_username, "black": black_username}
            elif black_username == username:
                player_games_data[idx + 1] = {black_username: black_outcome, white_username: white_outcome, "black": black_username, "white": white_username}

            # Who won?
            if white_outcome in lost_status:
                player_games_data[idx + 1]['whoWon'] = "black"
            elif white_outcome in draw_status:
                player_games_data[idx + 1]['whoWon'] = "draw"
            elif white_outcome in win_status:
                player_games_data[idx + 1]['whoWon'] = "white"
            
            player_games_data[idx + 1]['date'] = date_game
            player_games_data[idx + 1]['time'] = time_game
            
        return player_games_data

# %%
user_games_stored = player_games_history({},"Hikaru", current_year, current_month)

# %%
user_games_stored
# Out:
# {1: {'Hikaru': 'win',
#   'HansOnTwitch': 'resigned',
#   'black': 'Hikaru',
#   'white': 'HansOnTwitch',
#   'whoWon': 'black',
#   'date': '2022.04.02',
#   'time': '15:06:10'},
#  2: {'Hikaru': 'repetition',
#   'HansOnTwitch': 'repetition',
#   'white': 'Hikaru',
#   'black': 'HansOnTwitch',
#   'whoWon': 'draw',
#   'date': '2022.04.02',
#   'time': '15:11:49'},
#  3: {'Hikaru': 'win',
#   'HansOnTwitch': 'resigned',
#   'black': 'Hikaru',
#   'white': 'HansOnTwitch',
#   'whoWon': 'black',
#   'date': '2022.04.02',
#   'time': '15:15:00'},
#  4: {'Hikaru': 'win',
#   'HansOnTwitch': 'resigned',
#   'white': 'Hikaru',
#   'black': 'HansOnTwitch',
#   'whoWon': 'white',
#   'date': '2022.04.02',
#   'time': '15:20:20'},
#  5: {'Hikaru': 'resigned',
#   'Grischuk': 'win',
#   'black': 'Hikaru',
#   'white': 'Grischuk',
#   'whoWon': 'white',
#   'date': '2022.04.02',
#   'time': '16:16:17'},
#  6: {'Hikaru': 'resigned',
#   'Anton_Demchenko': 'win',
#   'white': 'Hikaru',
#   'black': 'Anton_Demchenko',
#   'whoWon': 'black',
#   'date': '2022.04.02',
#   'time': '16:36:38'},
#  7: {'Hikaru': 'win',
#   'dalmatinac101': 'resigned',
#   'black': 'Hikaru',
#   'white': 'dalmatinac101',
#   'whoWon': 'black',
#   'date': '2022.04.02',
#   'time': '17:01:31'},
#  8: {'Hikaru': 'repetition',
#   'HansOnTwitch': 'repetition',
#   'white': 'Hikaru',
#   'black': 'HansOnTwitch',
#   'whoWon': 'draw',
#   'date': '2022.04.02',
#   'time': '17:23:40'},
#  9: {'Hikaru': 'win',
#   'erichansen': 'resigned',
#   'black': 'Hikaru',
#   'white': 'erichansen',
#   'whoWon': 'black',
#   'date': '2022.04.02',
#   'time': '17:47:28'},
#  10: {'Hikaru': 'win',
#   'Jumbo': 'timeout',
#   'white': 'Hikaru',
#   'black': 'Jumbo',
#   'whoWon': 'white',
#   'date': '2022.04.02',
#   'time': '18:10:34'},
#  11: {'Hikaru': 'win',
#   'mishanick': 'resigned',
#   'black': 'Hikaru',
#   'white': 'mishanick',
#   'whoWon': 'black',
#   'date': '2022.04.02',
#   'time': '18:28:48'},
#  12: {'Hikaru': 'win',
#   'amintabatabaei': 'resigned',
#   'white': 'Hikaru',
#   'black': 'amintabatabaei',
#   'whoWon': 'white',
#   'date': '2022.04.02',
#   'time': '18:54:17'},
#  13: {'Hikaru': 'repetition',
#   'jefferyx': 'repetition',
#   'black': 'Hikaru',
#   'white': 'jefferyx',
#   'whoWon': 'draw',
#   'date': '2022.04.02',
#   'time': '18:58:20'},
#  14: {'Hikaru': 'resigned',
#   'ChessWarrior7197': 'win',
#   'white': 'Hikaru',
#   'black': 'ChessWarrior7197',
#   'whoWon': 'black',
#   'date': '2022.04.03',
#   'time': '16:53:39'},
#  15: {'Hikaru': 'win',
#   'FormerProdigy': 'resigned',
#   'black': 'Hikaru',
#   'white': 'FormerProdigy',
#   'whoWon': 'black',
#   'date': '2022.04.06',
#   'time': '16:04:09'},
#  16: {'Hikaru': 'win',
#   'Shiner22': 'resigned',
#   'black': 'Hikaru',
#   'white': 'Shiner22',
#   'whoWon': 'black',
#   'date': '2022.04.06',
#   'time': '16:07:52'},
#  17: {'Hikaru': 'win',
#   'XDPS': 'resigned',
#   'white': 'Hikaru',
#   'black': 'XDPS',
#   'whoWon': 'white',
#   'date': '2022.04.06',
#   'time': '16:13:53'},
#  18: {'Hikaru': 'win',
#   'Soltan49': 'checkmated',
#   'black': 'Hikaru',
#   'white': 'Soltan49',
#   'whoWon': 'black',
#   'date': '2022.04.06',
#   'time': '16:15:58'},
#  19: {'Hikaru': 'win',
#   'Azeryahu': 'resigned',
#   'white': 'Hikaru',
#   'black': 'Azeryahu',
#   'whoWon': 'white',
#   'date': '2022.04.06',
#   'time': '16:21:01'},
#  20: {'Hikaru': 'win',
#   'Airquake': 'resigned',
#   'black': 'Hikaru',
#   'white': 'Airquake',
#   'whoWon': 'black',
#   'date': '2022.04.06',
#   'time': '16:26:35'},
#  21: {'Hikaru': 'win',
#   'ErikRonka': 'resigned',
#   'white': 'Hikaru',
#   'black': 'ErikRonka',
#   'whoWon': 'white',
#   'date': '2022.04.06',
#   'time': '16:30:02'},
#  22: {'Hikaru': 'win',
#   'Aslanov_Umid': 'resigned',
#   'white': 'Hikaru',
#   'black': 'Aslanov_Umid',
#   'whoWon': 'white',
#   'date': '2022.04.06',
#   'time': '16:34:14'},
#  23: {'Hikaru': 'win',
#   'Azeryahu': 'timeout',
#   'black': 'Hikaru',
#   'white': 'Azeryahu',
#   'whoWon': 'black',
#   'date': '2022.04.06',
#   'time': '16:40:24'},
#  24: {'Hikaru': 'win',
#   'MITerryble': 'timeout',
#   'black': 'Hikaru',
#   'white': 'MITerryble',
#   'whoWon': 'black',
#   'date': '2022.04.06',
#   'time': '16:46:36'},
#  25: {'Hikaru': 'win',
#   'AtabayevSaparmyrat': 'resigned',
#   'white': 'Hikaru',
#   'black': 'AtabayevSaparmyrat',
#   'whoWon': 'white',
#   'date': '2022.04.06',
#   'time': '16:48:38'},
#  26: {'Hikaru': 'win',
#   'Azeryahu': 'resigned',
#   'white': 'Hikaru',
#   'black': 'Azeryahu',
#   'whoWon': 'white',
#   'date': '2022.04.06',
#   'time': '16:51:28'},
#  27: {'Hikaru': 'win',
#   'Airquake': 'resigned',
#   'white': 'Hikaru',
#   'black': 'Airquake',
#   'whoWon': 'white',
#   'date': '2022.04.06',
#   'time': '16:55:59'},
#  28: {'Hikaru': 'win',
#   'Artem_Sadovsky': 'checkmated',
#   'white': 'Hikaru',
#   'black': 'Artem_Sadovsky',
#   'whoWon': 'white',
#   'date': '2022.04.06',
#   'time': '16:59:33'},
#  29: {'Hikaru': 'win',
#   'Ward-Tsh': 'resigned',
#   'black': 'Hikaru',
#   'white': 'Ward-Tsh',
#   'whoWon': 'black',
#   'date': '2022.04.06',
#   'time': '17:05:40'},
#  30: {'Hikaru': 'win',
#   'ErikRonka': 'resigned',
#   'black': 'Hikaru',
#   'white': 'ErikRonka',
#   'whoWon': 'black',
#   'date': '2022.04.06',
#   'time': '17:08:29'},
#  31: {'Hikaru': 'win',
#   'alexrustemov': 'resigned',
#   'white': 'Hikaru',
#   'black': 'alexrustemov',
#   'whoWon': 'white',
#   'date': '2022.04.06',
#   'time': '17:13:33'},
#  32: {'Hikaru': 'win',
#   'Sychev_on_YouTube': 'resigned',
#   'white': 'Hikaru',
#   'black': 'Sychev_on_YouTube',
#   'whoWon': 'white',
#   'date': '2022.04.06',
#   'time': '17:14:40'},
#  33: {'Hikaru': 'repetition',
#   'Jospem': 'repetition',
#   'white': 'Hikaru',
#   'black': 'Jospem',
#   'whoWon': 'draw',
#   'date': '2022.04.06',
#   'time': '17:20:29'},
#  34: {'Hikaru': 'win',
#   'GMrbigbizzness': 'timeout',
#   'black': 'Hikaru',
#   'white': 'GMrbigbizzness',
#   'whoWon': 'black',
#   'date': '2022.04.06',
#   'time': '17:25:13'},
#  35: {'Hikaru': 'win',
#   'Orest_Vovk': 'resigned',
#   'black': 'Hikaru',
#   'white': 'Orest_Vovk',
#   'whoWon': 'black',
#   'date': '2022.04.06',
#   'time': '17:30:56'},
#  36: {'Hikaru': 'win',
#   'FritziSchach_Twitch': 'resigned',
#   'black': 'Hikaru',
#   'white': 'FritziSchach_Twitch',
#   'whoWon': 'black',
#   'date': '2022.04.06',
#   'time': '17:35:56'},
#  37: {'Hikaru': 'win',
#   'Filippos2009': 'resigned',
#   'white': 'Hikaru',
#   'black': 'Filippos2009',
#   'whoWon': 'white',
#   'date': '2022.04.06',
#   'time': '17:38:15'},
#  38: {'Hikaru': 'win',
#   'wonderfultime': 'resigned',
#   'black': 'Hikaru',
#   'white': 'wonderfultime',
#   'whoWon': 'black',
#   'date': '2022.04.06',
#   'time': '17:40:39'},
#  39: {'Hikaru': 'win',
#   'UncoverOpportunities': 'checkmated',
#   'black': 'Hikaru',
#   'white': 'UncoverOpportunities',
#   'whoWon': 'black',
#   'date': '2022.04.06',
#   'time': '17:45:46'},
#  40: {'Hikaru': 'win',
#   'Kacparov': 'resigned',
#   'white': 'Hikaru',
#   'black': 'Kacparov',
#   'whoWon': 'white',
#   'date': '2022.04.06',
#   'time': '17:51:26'},
#  41: {'Hikaru': 'win',
#   'MITerryble': 'resigned',
#   'white': 'Hikaru',
#   'black': 'MITerryble',
#   'whoWon': 'white',
#   'date': '2022.04.06',
#   'time': '17:54:08'},
#  42: {'Hikaru': 'win',
#   'Oleksandr_Bortnyk': 'checkmated',
#   'white': 'Hikaru',
#   'black': 'Oleksandr_Bortnyk',
#   'whoWon': 'white',
#   'date': '2022.04.06',
#   'time': '17:58:39'},
#  43: {'Hikaru': 'win',
#   'VallabhTFT': 'resigned',
#   'white': 'Hikaru',
#   'black': 'VallabhTFT',
#   'whoWon': 'white',
#   'date': '2022.04.06',
#   'time': '18:20:13'},
#  44: {'Hikaru': 'win',
#   'VallabhTFT': 'resigned',
#   'black': 'Hikaru',
#   'white': 'VallabhTFT',
#   'whoWon': 'black',
#   'date': '2022.04.06',
#   'time': '18:23:59'},
#  45: {'Hikaru': 'win',
#   'SlipperySpeedster': 'resigned',
#   'white': 'Hikaru',
#   'black': 'SlipperySpeedster',
#   'whoWon': 'white',
#   'date': '2022.04.06',
#   'time': '18:45:19'},
#  46: {'Hikaru': 'win',
#   'SlipperySpeedster': 'resigned',
#   'black': 'Hikaru',
#   'white': 'SlipperySpeedster',
#   'whoWon': 'black',
#   'date': '2022.04.06',
#   'time': '18:47:38'},
#  47: {'Hikaru': 'resigned',
#   'wonderfultime': 'win',
#   'white': 'Hikaru',
#   'black': 'wonderfultime',
#   'whoWon': 'black',
#   'date': '2022.04.06',
#   'time': '19:13:04'},
#  48: {'Hikaru': 'win',
#   'wonderfultime': 'resigned',
#   'black': 'Hikaru',
#   'white': 'wonderfultime',
#   'whoWon': 'black',
#   'date': '2022.04.06',
#   'time': '19:17:30'},
#  49: {'Hikaru': 'win',
#   'wonderfultime': 'timeout',
#   'white': 'Hikaru',
#   'black': 'wonderfultime',
#   'whoWon': 'white',
#   'date': '2022.04.06',
#   'time': '19:23:51'},
#  50: {'Hikaru': 'win',
#   'Oleksandr_Bortnyk': 'resigned',
#   'white': 'Hikaru',
#   'black': 'Oleksandr_Bortnyk',
#   'whoWon': 'white',
#   'date': '2022.04.06',
#   'time': '19:52:27'},
#  51: {'Hikaru': 'win',
#   'Oleksandr_Bortnyk': 'timeout',
#   'black': 'Hikaru',
#   'white': 'Oleksandr_Bortnyk',
#   'whoWon': 'black',
#   'date': '2022.04.06',
#   'time': '19:58:36'},
#  52: {'Hikaru': 'resigned',
#   'Oleksandr_Bortnyk': 'win',
#   'white': 'Hikaru',
#   'black': 'Oleksandr_Bortnyk',
#   'whoWon': 'black',
#   'date': '2022.04.06',
#   'time': '20:01:51'},
#  53: {'Hikaru': 'win',
#   'Oleksandr_Bortnyk': 'resigned',
#   'black': 'Hikaru',
#   'white': 'Oleksandr_Bortnyk',
#   'whoWon': 'black',
#   'date': '2022.04.06',
#   'time': '20:07:32'},
#  54: {'Hikaru': 'win',
#   'alexrustemov': 'timeout',
#   'black': 'Hikaru',
#   'white': 'alexrustemov',
#   'whoWon': 'black',
#   'date': '2022.04.07',
#   'time': '15:53:58'},
#  55: {'Hikaru': 'win',
#   'alexrustemov': 'resigned',
#   'white': 'Hikaru',
#   'black': 'alexrustemov',
#   'whoWon': 'white',
#   'date': '2022.04.07',
#   'time': '15:59:52'},
#  56: {'Hikaru': 'win',
#   'alexrustemov': 'resigned',
#   'black': 'Hikaru',
#   'white': 'alexrustemov',
#   'whoWon': 'black',
#   'date': '2022.04.07',
#   'time': '16:04:23'},
#  57: {'Hikaru': 'win',
#   'alexrustemov': 'resigned',
#   'white': 'Hikaru',
#   'black': 'alexrustemov',
#   'whoWon': 'white',
#   'date': '2022.04.07',
#   'time': '16:09:38'},
#  58: {'Hikaru': 'win',
#   'alexrustemov': 'resigned',
#   'black': 'Hikaru',
#   'white': 'alexrustemov',
#   'whoWon': 'black',
#   'date': '2022.04.07',
#   'time': '16:14:31'},
#  59: {'Hikaru': 'win',
#   'MITerryble': 'resigned',
#   'black': 'Hikaru',
#   'white': 'MITerryble',
#   'whoWon': 'black',
#   'date': '2022.04.07',
#   'time': '16:20:08'},
#  60: {'Hikaru': 'win',
#   'MITerryble': 'timeout',
#   'white': 'Hikaru',
#   'black': 'MITerryble',
#   'whoWon': 'white',
#   'date': '2022.04.07',
#   'time': '16:26:28'},
#  61: {'Hikaru': 'win',
#   'MITerryble': 'timeout',
#   'black': 'Hikaru',
#   'white': 'MITerryble',
#   'whoWon': 'black',
#   'date': '2022.04.07',
#   'time': '16:32:18'},
#  62: {'Hikaru': 'win',
#   'MITerryble': 'timeout',
#   'white': 'Hikaru',
#   'black': 'MITerryble',
#   'whoWon': 'white',
#   'date': '2022.04.07',
#   'time': '16:38:26'},
#  63: {'Hikaru': 'resigned',
#   'MITerryble': 'win',
#   'black': 'Hikaru',
#   'white': 'MITerryble',
#   'whoWon': 'white',
#   'date': '2022.04.07',
#   'time': '16:43:58'},
#  64: {'Hikaru': 'win',
#   'MITerryble': 'resigned',
#   'white': 'Hikaru',
#   'black': 'MITerryble',
#   'whoWon': 'white',
#   'date': '2022.04.07',
#   'time': '16:48:43'},
#  65: {'Hikaru': 'win',
#   'Oleksandr_Bortnyk': 'resigned',
#   'white': 'Hikaru',
#   'black': 'Oleksandr_Bortnyk',
#   'whoWon': 'white',
#   'date': '2022.04.07',
#   'time': '16:53:32'},
#  66: {'Hikaru': 'win',
#   'Oleksandr_Bortnyk': 'resigned',
#   'black': 'Hikaru',
#   'white': 'Oleksandr_Bortnyk',
#   'whoWon': 'black',
#   'date': '2022.04.07',
#   'time': '16:58:21'},
#  67: {'Hikaru': 'win',
#   'Oleksandr_Bortnyk': 'timeout',
#   'white': 'Hikaru',
#   'black': 'Oleksandr_Bortnyk',
#   'whoWon': 'white',
#   'date': '2022.04.07',
#   'time': '17:04:25'},
#  68: {'Hikaru': 'win',
#   'NikoTheodorou': 'resigned',
#   'black': 'Hikaru',
#   'white': 'NikoTheodorou',
#   'whoWon': 'black',
#   'date': '2022.04.08',
#   'time': '15:44:07'},
#  69: {'Hikaru': 'resigned',
#   'NikoTheodorou': 'win',
#   'white': 'Hikaru',
#   'black': 'NikoTheodorou',
#   'whoWon': 'black',
#   'date': '2022.04.08',
#   'time': '15:48:40'},
#  70: {'Hikaru': 'win',
#   'NikoTheodorou': 'resigned',
#   'black': 'Hikaru',
#   'white': 'NikoTheodorou',
#   'whoWon': 'black',
#   'date': '2022.04.08',
#   'time': '15:52:01'},
#  71: {'Hikaru': 'win',
#   'NikoTheodorou': 'resigned',
#   'white': 'Hikaru',
#   'black': 'NikoTheodorou',
#   'whoWon': 'white',
#   'date': '2022.04.08',
#   'time': '15:54:45'},
#  72: {'Hikaru': 'resigned',
#   'NikoTheodorou': 'win',
#   'black': 'Hikaru',
#   'white': 'NikoTheodorou',
#   'whoWon': 'white',
#   'date': '2022.04.08',
#   'time': '15:59:15'},
#  73: {'Hikaru': 'win',
#   'NikoTheodorou': 'resigned',
#   'white': 'Hikaru',
#   'black': 'NikoTheodorou',
#   'whoWon': 'white',
#   'date': '2022.04.08',
#   'time': '16:03:09'},
#  74: {'Hikaru': 'win',
#   'NikoTheodorou': 'resigned',
#   'black': 'Hikaru',
#   'white': 'NikoTheodorou',
#   'whoWon': 'black',
#   'date': '2022.04.08',
#   'time': '16:08:31'},
#  75: {'Hikaru': 'win',
#   'NikoTheodorou': 'resigned',
#   'white': 'Hikaru',
#   'black': 'NikoTheodorou',
#   'whoWon': 'white',
#   'date': '2022.04.08',
#   'time': '16:13:24'},
#  76: {'Hikaru': 'win',
#   'NikoTheodorou': 'resigned',
#   'black': 'Hikaru',
#   'white': 'NikoTheodorou',
#   'whoWon': 'black',
#   'date': '2022.04.08',
#   'time': '16:18:28'},
#  77: {'Hikaru': 'repetition',
#   'NikoTheodorou': 'repetition',
#   'white': 'Hikaru',
#   'black': 'NikoTheodorou',
#   'whoWon': 'draw',
#   'date': '2022.04.08',
#   'time': '16:23:34'},
#  78: {'Hikaru': 'win',
#   'NikoTheodorou': 'resigned',
#   'black': 'Hikaru',
#   'white': 'NikoTheodorou',
#   'whoWon': 'black',
#   'date': '2022.04.08',
#   'time': '16:28:48'},
#  79: {'Hikaru': 'win',
#   'NikoTheodorou': 'timeout',
#   'white': 'Hikaru',
#   'black': 'NikoTheodorou',
#   'whoWon': 'white',
#   'date': '2022.04.08',
#   'time': '16:34:57'},
#  80: {'Hikaru': 'win',
#   'NikoTheodorou': 'resigned',
#   'black': 'Hikaru',
#   'white': 'NikoTheodorou',
#   'whoWon': 'black',
#   'date': '2022.04.08',
#   'time': '16:40:55'},
#  81: {'Hikaru': 'win',
#   'NikoTheodorou': 'resigned',
#   'white': 'Hikaru',
#   'black': 'NikoTheodorou',
#   'whoWon': 'white',
#   'date': '2022.04.08',
#   'time': '16:46:26'},
#  82: {'Hikaru': 'timeout',
#   'NikoTheodorou': 'win',
#   'black': 'Hikaru',
#   'white': 'NikoTheodorou',
#   'whoWon': 'white',
#   'date': '2022.04.08',
#   'time': '16:52:14'},
#  83: {'Hikaru': 'repetition',
#   'Andreikka': 'repetition',
#   'white': 'Hikaru',
#   'black': 'Andreikka',
#   'whoWon': 'draw',
#   'date': '2022.04.08',
#   'time': '17:17:39'},
#  84: {'Hikaru': 'win',
#   'Andreikka': 'resigned',
#   'black': 'Hikaru',
#   'white': 'Andreikka',
#   'whoWon': 'black',
#   'date': '2022.04.08',
#   'time': '17:22:47'},
#  85: {'Hikaru': 'win',
#   'Andreikka': 'resigned',
#   'white': 'Hikaru',
#   'black': 'Andreikka',
#   'whoWon': 'white',
#   'date': '2022.04.08',
#   'time': '17:28:18'},
#  86: {'Hikaru': 'agreed',
#   'Andreikka': 'agreed',
#   'black': 'Hikaru',
#   'white': 'Andreikka',
#   'whoWon': 'draw',
#   'date': '2022.04.08',
#   'time': '17:34:09'},
#  87: {'Hikaru': 'win',
#   'Andreikka': 'resigned',
#   'white': 'Hikaru',
#   'black': 'Andreikka',
#   'whoWon': 'white',
#   'date': '2022.04.08',
#   'time': '17:39:27'},
#  88: {'Hikaru': 'win',
#   'Andreikka': 'resigned',
#   'black': 'Hikaru',
#   'white': 'Andreikka',
#   'whoWon': 'black',
#   'date': '2022.04.08',
#   'time': '17:44:11'},
#  89: {'Hikaru': 'checkmated',
#   'Andreikka': 'win',
#   'white': 'Hikaru',
#   'black': 'Andreikka',
#   'whoWon': 'black',
#   'date': '2022.04.08',
#   'time': '17:50:21'},
#  90: {'Hikaru': 'insufficient',
#   'Andreikka': 'insufficient',
#   'black': 'Hikaru',
#   'white': 'Andreikka',
#   'date': '2022.04.08',
#   'time': '17:56:34'},
#  91: {'Hikaru': 'agreed',
#   'Andreikka': 'agreed',
#   'white': 'Hikaru',
#   'black': 'Andreikka',
#   'whoWon': 'draw',
#   'date': '2022.04.08',
#   'time': '18:02:16'},
#  92: {'Hikaru': 'win',
#   'Jospem': 'resigned',
#   'black': 'Hikaru',
#   'white': 'Jospem',
#   'whoWon': 'black',
#   'date': '2022.04.08',
#   'time': '18:11:49'},
#  93: {'Hikaru': 'win',
#   'Jospem': 'resigned',
#   'white': 'Hikaru',
#   'black': 'Jospem',
#   'whoWon': 'white',
#   'date': '2022.04.08',
#   'time': '18:17:32'},
#  94: {'Hikaru': 'win',
#   'Jospem': 'resigned',
#   'black': 'Hikaru',
#   'white': 'Jospem',
#   'whoWon': 'black',
#   'date': '2022.04.08',
#   'time': '18:22:58'},
#  95: {'Hikaru': 'win',
#   'Jospem': 'resigned',
#   'white': 'Hikaru',
#   'black': 'Jospem',
#   'whoWon': 'white',
#   'date': '2022.04.08',
#   'time': '18:26:10'},
#  96: {'Hikaru': 'win',
#   'Jospem': 'resigned',
#   'black': 'Hikaru',
#   'white': 'Jospem',
#   'whoWon': 'black',
#   'date': '2022.04.08',
#   'time': '18:30:09'},
#  97: {'Hikaru': 'win',
#   'Jospem': 'resigned',
#   'white': 'Hikaru',
#   'black': 'Jospem',
#   'whoWon': 'white',
#   'date': '2022.04.08',
#   'time': '18:35:21'},
#  98: {'Hikaru': 'win',
#   'Jospem': 'resigned',
#   'black': 'Hikaru',
#   'white': 'Jospem',
#   'whoWon': 'black',
#   'date': '2022.04.08',
#   'time': '18:40:54'},
#  99: {'Hikaru': 'win',
#   'Jospem': 'resigned',
#   'white': 'Hikaru',
#   'black': 'Jospem',
#   'whoWon': 'white',
#   'date': '2022.04.08',
#   'time': '18:45:12'},
#  100: {'Hikaru': 'win',
#   'Jospem': 'resigned',
#   'black': 'Hikaru',
#   'white': 'Jospem',
#   'whoWon': 'black',
#   'date': '2022.04.08',
#   'time': '18:50:33'},
#  101: {'Hikaru': 'resigned',
#   'Jospem': 'win',
#   'white': 'Hikaru',
#   'black': 'Jospem',
#   'whoWon': 'black',
#   'date': '2022.04.08',
#   'time': '18:56:38'},
#  102: {'Hikaru': 'win',
#   'Jospem': 'resigned',
#   'black': 'Hikaru',
#   'white': 'Jospem',
#   'whoWon': 'black',
#   'date': '2022.04.08',
#   'time': '19:00:40'},
#  103: {'Hikaru': 'win',
#   'Jospem': 'resigned',
#   'white': 'Hikaru',
#   'black': 'Jospem',
#   'whoWon': 'white',
#   'date': '2022.04.08',
#   'time': '19:06:26'},
#  104: {'Hikaru': 'win',
#   'Jospem': 'timeout',
#   'black': 'Hikaru',
#   'white': 'Jospem',
#   'whoWon': 'black',
#   'date': '2022.04.08',
#   'time': '19:12:37'},
#  105: {'Hikaru': 'win',
#   'Indianlad': 'resigned',
#   'white': 'Hikaru',
#   'black': 'Indianlad',
#   'whoWon': 'white',
#   'date': '2022.04.09',
#   'time': '16:13:47'},
#  106: {'Hikaru': 'agreed',
#   'mishanick': 'agreed',
#   'black': 'Hikaru',
#   'white': 'mishanick',
#   'whoWon': 'draw',
#   'date': '2022.04.09',
#   'time': '16:33:46'},
#  107: {'Hikaru': 'repetition',
#   'GMWSO': 'repetition',
#   'white': 'Hikaru',
#   'black': 'GMWSO',
#   'whoWon': 'draw',
#   'date': '2022.04.09',
#   'time': '17:00:45'},
#  108: {'Hikaru': 'repetition',
#   'Jospem': 'repetition',
#   'black': 'Hikaru',
#   'white': 'Jospem',
#   'whoWon': 'draw',
#   'date': '2022.04.09',
#   'time': '17:19:11'},
#  109: {'Hikaru': 'win',
#   'BillieKimbah': 'resigned',
#   'white': 'Hikaru',
#   'black': 'BillieKimbah',
#   'whoWon': 'white',
#   'date': '2022.04.09',
#   'time': '17:46:56'},
#  110: {'Hikaru': 'win',
#   'amintabatabaei': 'resigned',
#   'white': 'Hikaru',
#   'black': 'amintabatabaei',
#   'whoWon': 'white',
#   'date': '2022.04.09',
#   'time': '18:11:32'},
#  111: {'Hikaru': 'agreed',
#   'Bigfish1995': 'agreed',
#   'black': 'Hikaru',
#   'white': 'Bigfish1995',
#   'whoWon': 'draw',
#   'date': '2022.04.09',
#   'time': '18:13:55'},
#  112: {'Hikaru': 'repetition',
#   'LevonAronian': 'repetition',
#   'black': 'Hikaru',
#   'white': 'LevonAronian',
#   'whoWon': 'draw',
#   'date': '2022.04.09',
#   'time': '18:34:09'},
#  113: {'Hikaru': 'insufficient',
#   'Grischuk': 'insufficient',
#   'white': 'Hikaru',
#   'black': 'Grischuk',
#   'date': '2022.04.09',
#   'time': '19:13:48'},
#  114: {'Hikaru': 'win',
#   'Grischuk': 'resigned',
#   'white': 'Hikaru',
#   'black': 'Grischuk',
#   'whoWon': 'white',
#   'date': '2022.04.10',
#   'time': '16:55:15'},
#  115: {'Hikaru': 'repetition',
#   'Bigfish1995': 'repetition',
#   'black': 'Hikaru',
#   'white': 'Bigfish1995',
#   'whoWon': 'draw',
#   'date': '2022.04.10',
#   'time': '18:49:02'},
#  116: {'Hikaru': 'win',
#   'Bigfish1995': 'resigned',
#   'white': 'Hikaru',
#   'black': 'Bigfish1995',
#   'whoWon': 'white',
#   'date': '2022.04.10',
#   'time': '18:58:28'},
#  117: {'Hikaru': 'win',
#   'LevonAronian': 'resigned',
#   'black': 'Hikaru',
#   'white': 'LevonAronian',
#   'whoWon': 'black',
#   'date': '2022.04.10',
#   'time': '19:52:05'},
#  118: {'Hikaru': 'agreed',
#   'Baku_Boulevard': 'agreed',
#   'black': 'Hikaru',
#   'white': 'Baku_Boulevard',
#   'whoWon': 'draw',
#   'date': '2022.04.11',
#   'time': '13:02:02'},
#  119: {'Hikaru': 'win',
#   'Baku_Boulevard': 'resigned',
#   'white': 'Hikaru',
#   'black': 'Baku_Boulevard',
#   'whoWon': 'white',
#   'date': '2022.04.11',
#   'time': '13:07:05'},
#  120: {'Hikaru': 'win',
#   'Baku_Boulevard': 'resigned',
#   'black': 'Hikaru',
#   'white': 'Baku_Boulevard',
#   'whoWon': 'black',
#   'date': '2022.04.11',
#   'time': '13:12:06'},
#  121: {'Hikaru': 'win',
#   'Baku_Boulevard': 'checkmated',
#   'white': 'Hikaru',
#   'black': 'Baku_Boulevard',
#   'whoWon': 'white',
#   'date': '2022.04.11',
#   'time': '13:18:45'},
#  122: {'Hikaru': 'repetition',
#   'Baku_Boulevard': 'repetition',
#   'black': 'Hikaru',
#   'white': 'Baku_Boulevard',
#   'whoWon': 'draw',
#   'date': '2022.04.11',
#   'time': '13:24:46'},
#  123: {'Hikaru': 'checkmated',
#   'Baku_Boulevard': 'win',
#   'white': 'Hikaru',
#   'black': 'Baku_Boulevard',
#   'whoWon': 'black',
#   'date': '2022.04.11',
#   'time': '13:31:08'},
#  124: {'Hikaru': 'resigned',
#   'Baku_Boulevard': 'win',
#   'black': 'Hikaru',
#   'white': 'Baku_Boulevard',
#   'whoWon': 'white',
#   'date': '2022.04.11',
#   'time': '13:34:08'},
#  125: {'Hikaru': 'win',
#   'Baku_Boulevard': 'resigned',
#   'white': 'Hikaru',
#   'black': 'Baku_Boulevard',
#   'whoWon': 'white',
#   'date': '2022.04.11',
#   'time': '13:38:12'},
#  126: {'Hikaru': 'resigned',
#   'Baku_Boulevard': 'win',
#   'black': 'Hikaru',
#   'white': 'Baku_Boulevard',
#   'whoWon': 'white',
#   'date': '2022.04.11',
#   'time': '13:42:49'},
#  127: {'Hikaru': 'win',
#   'Baku_Boulevard': 'resigned',
#   'white': 'Hikaru',
#   'black': 'Baku_Boulevard',
#   'whoWon': 'white',
#   'date': '2022.04.11',
#   'time': '13:48:24'},
#  128: {'Hikaru': 'win',
#   'Sam_ChessMood': 'resigned',
#   'white': 'Hikaru',
#   'black': 'Sam_ChessMood',
#   'whoWon': 'white',
#   'date': '2022.04.11',
#   'time': '13:56:50'},
#  129: {'Hikaru': 'win',
#   'Sam_ChessMood': 'resigned',
#   'black': 'Hikaru',
#   'white': 'Sam_ChessMood',
#   'whoWon': 'black',
#   'date': '2022.04.11',
#   'time': '13:59:31'},
#  130: {'Hikaru': 'win',
#   'Sam_ChessMood': 'timeout',
#   'white': 'Hikaru',
#   'black': 'Sam_ChessMood',
#   'whoWon': 'white',
#   'date': '2022.04.11',
#   'time': '14:05:29'},
#  131: {'Hikaru': 'resigned',
#   'Sam_ChessMood': 'win',
#   'black': 'Hikaru',
#   'white': 'Sam_ChessMood',
#   'whoWon': 'white',
#   'date': '2022.04.11',
#   'time': '14:10:55'},
#  132: {'Hikaru': 'win',
#   'Sam_ChessMood': 'resigned',
#   'white': 'Hikaru',
#   'black': 'Sam_ChessMood',
#   'whoWon': 'white',
#   'date': '2022.04.11',
#   'time': '14:15:56'},
#  133: {'Hikaru': 'win',
#   'Sam_ChessMood': 'timeout',
#   'black': 'Hikaru',
#   'white': 'Sam_ChessMood',
#   'whoWon': 'black',
#   'date': '2022.04.11',
#   'time': '14:21:45'},
#  134: {'Hikaru': 'win',
#   'vi_pranav': 'resigned',
#   'black': 'Hikaru',
#   'white': 'vi_pranav',
#   'whoWon': 'black',
#   'date': '2022.04.11',
#   'time': '14:59:00'},
#  135: {'Hikaru': 'win',
#   'vi_pranav': 'resigned',
#   'white': 'Hikaru',
#   'black': 'vi_pranav',
#   'whoWon': 'white',
#   'date': '2022.04.11',
#   'time': '15:02:39'},
#  136: {'Hikaru': 'win',
#   'vi_pranav': 'checkmated',
#   'black': 'Hikaru',
#   'white': 'vi_pranav',
#   'whoWon': 'black',
#   'date': '2022.04.11',
#   'time': '15:09:12'},
#  137: {'Hikaru': 'win',
#   'vi_pranav': 'resigned',
#   'white': 'Hikaru',
#   'black': 'vi_pranav',
#   'whoWon': 'white',
#   'date': '2022.04.11',
#   'time': '15:14:23'},
#  138: {'Hikaru': 'win',
#   'vi_pranav': 'resigned',
#   'black': 'Hikaru',
#   'white': 'vi_pranav',
#   'whoWon': 'black',
#   'date': '2022.04.11',
#   'time': '15:19:26'},
#  139: {'Hikaru': 'resigned',
#   'vi_pranav': 'win',
#   'white': 'Hikaru',
#   'black': 'vi_pranav',
#   'whoWon': 'black',
#   'date': '2022.04.11',
#   'time': '15:24:52'},
#  140: {'Hikaru': 'resigned',
#   'vi_pranav': 'win',
#   'black': 'Hikaru',
#   'white': 'vi_pranav',
#   'whoWon': 'white',
#   'date': '2022.04.11',
#   'time': '15:29:46'},
#  141: {'Hikaru': 'win',
#   'vi_pranav': 'resigned',
#   'white': 'Hikaru',
#   'black': 'vi_pranav',
#   'whoWon': 'white',
#   'date': '2022.04.11',
#   'time': '15:34:46'},
#  142: {'Hikaru': 'resigned',
#   'vi_pranav': 'win',
#   'black': 'Hikaru',
#   'white': 'vi_pranav',
#   'whoWon': 'white',
#   'date': '2022.04.11',
#   'time': '15:40:13'},
#  143: {'Hikaru': 'win',
#   'vi_pranav': 'resigned',
#   'white': 'Hikaru',
#   'black': 'vi_pranav',
#   'whoWon': 'white',
#   'date': '2022.04.11',
#   'time': '15:43:27'},
#  144: {'Hikaru': 'win',
#   'vi_pranav': 'resigned',
#   'black': 'Hikaru',
#   'white': 'vi_pranav',
#   'whoWon': 'black',
#   'date': '2022.04.11',
#   'time': '15:46:07'},
#  145: {'Hikaru': 'win',
#   'vi_pranav': 'resigned',
#   'white': 'Hikaru',
#   'black': 'vi_pranav',
#   'whoWon': 'white',
#   'date': '2022.04.11',
#   'time': '15:50:26'},
#  146: {'Hikaru': 'win',
#   'vi_pranav': 'resigned',
#   'black': 'Hikaru',
#   'white': 'vi_pranav',
#   'whoWon': 'black',
#   'date': '2022.04.11',
#   'time': '15:55:44'},
#  147: {'Hikaru': 'win',
#   'vi_pranav': 'resigned',
#   'white': 'Hikaru',
#   'black': 'vi_pranav',
#   'whoWon': 'white',
#   'date': '2022.04.11',
#   'time': '15:57:55'},
#  148: {'Hikaru': 'win',
#   'vi_pranav': 'resigned',
#   'black': 'Hikaru',
#   'white': 'vi_pranav',
#   'whoWon': 'black',
#   'date': '2022.04.11',
#   'time': '16:03:04'},
#  149: {'Hikaru': 'resigned',
#   'Oleksandr_Bortnyk': 'win',
#   'black': 'Hikaru',
#   'white': 'Oleksandr_Bortnyk',
#   'whoWon': 'white',
#   'date': '2022.04.11',
#   'time': '16:10:11'},
#  150: {'Hikaru': 'win',
#   'Oleksandr_Bortnyk': 'resigned',
#   'white': 'Hikaru',
#   'black': 'Oleksandr_Bortnyk',
#   'whoWon': 'white',
#   'date': '2022.04.11',
#   'time': '16:14:42'},
#  151: {'Hikaru': 'agreed',
#   'Oleksandr_Bortnyk': 'agreed',
#   'black': 'Hikaru',
#   'white': 'Oleksandr_Bortnyk',
#   'whoWon': 'draw',
#   'date': '2022.04.11',
#   'time': '16:18:38'},
#  152: {'Hikaru': 'win',
#   'Oleksandr_Bortnyk': 'resigned',
#   'white': 'Hikaru',
#   'black': 'Oleksandr_Bortnyk',
#   'whoWon': 'white',
#   'date': '2022.04.11',
#   'time': '16:22:52'},
#  153: {'Hikaru': 'win',
#   'Oleksandr_Bortnyk': 'timeout',
#   'black': 'Hikaru',
#   'white': 'Oleksandr_Bortnyk',
#   'whoWon': 'black',
#   'date': '2022.04.11',
#   'time': '16:28:43'},
#  154: {'Hikaru': 'win',
#   'Oleksandr_Bortnyk': 'resigned',
#   'white': 'Hikaru',
#   'black': 'Oleksandr_Bortnyk',
#   'whoWon': 'white',
#   'date': '2022.04.11',
#   'time': '16:33:50'},
#  155: {'Hikaru': 'timevsinsufficient',
#   'Oleksandr_Bortnyk': 'timevsinsufficient',
#   'black': 'Hikaru',
#   'white': 'Oleksandr_Bortnyk',
#   'date': '2022.04.11',
#   'time': '16:39:46'},
#  156: {'Hikaru': 'win',
#   'Oleksandr_Bortnyk': 'checkmated',
#   'white': 'Hikaru',
#   'black': 'Oleksandr_Bortnyk',
#   'whoWon': 'white',
#   'date': '2022.04.11',
#   'time': '16:45:26'},
#  157: {'Hikaru': 'win',
#   'Oleksandr_Bortnyk': 'resigned',
#   'black': 'Hikaru',
#   'white': 'Oleksandr_Bortnyk',
#   'whoWon': 'black',
#   'date': '2022.04.11',
#   'time': '16:50:25'},
#  158: {'Hikaru': 'win',
#   'Oleksandr_Bortnyk': 'resigned',
#   'white': 'Hikaru',
#   'black': 'Oleksandr_Bortnyk',
#   'whoWon': 'white',
#   'date': '2022.04.11',
#   'time': '16:55:45'},
#  159: {'Hikaru': 'win',
#   'Oleksandr_Bortnyk': 'resigned',
#   'black': 'Hikaru',
#   'white': 'Oleksandr_Bortnyk',
#   'whoWon': 'black',
#   'date': '2022.04.11',
#   'time': '17:01:39'},
#  160: {'Hikaru': 'win',
#   'Oleksandr_Bortnyk': 'resigned',
#   'white': 'Hikaru',
#   'black': 'Oleksandr_Bortnyk',
#   'whoWon': 'white',
#   'date': '2022.04.11',
#   'time': '17:06:27'},
#  161: {'Hikaru': 'insufficient',
#   'Oleksandr_Bortnyk': 'insufficient',
#   'black': 'Hikaru',
#   'white': 'Oleksandr_Bortnyk',
#   'date': '2022.04.11',
#   'time': '17:12:54'},
#  162: {'Hikaru': 'win',
#   'js20000': 'timeout',
#   'black': 'Hikaru',
#   'white': 'js20000',
#   'whoWon': 'black',
#   'date': '2022.04.12',
#   'time': '15:06:11'},
#  163: {'Hikaru': 'win',
#   'Legendinunknown': 'checkmated',
#   'white': 'Hikaru',
#   'black': 'Legendinunknown',
#   'whoWon': 'white',
#   'date': '2022.04.12',
#   'time': '15:15:23'},
#  164: {'Hikaru': 'win',
#   'alexrustemov': 'resigned',
#   'black': 'Hikaru',
#   'white': 'alexrustemov',
#   'whoWon': 'black',
#   'date': '2022.04.12',
#   'time': '15:26:48'},
#  165: {'Hikaru': 'checkmated',
#   'Sanan_Sjugirov': 'win',
#   'white': 'Hikaru',
#   'black': 'Sanan_Sjugirov',
#   'whoWon': 'black',
#   'date': '2022.04.12',
#   'time': '15:36:49'},
#  166: {'Hikaru': 'win',
#   'Disturbed01': 'resigned',
#   'black': 'Hikaru',
#   'white': 'Disturbed01',
#   'whoWon': 'black',
#   'date': '2022.04.12',
#   'time': '15:52:30'},
#  167: {'Hikaru': 'win',
#   'GM_shahin': 'checkmated',
#   'white': 'Hikaru',
#   'black': 'GM_shahin',
#   'whoWon': 'white',
#   'date': '2022.04.12',
#   'time': '16:05:13'},
#  168: {'Hikaru': 'win',
#   'BillieKimbah': 'resigned',
#   'black': 'Hikaru',
#   'white': 'BillieKimbah',
#   'whoWon': 'black',
#   'date': '2022.04.12',
#   'time': '16:14:37'},
#  169: {'Hikaru': 'resigned',
#   'ChessWarrior7197': 'win',
#   'white': 'Hikaru',
#   'black': 'ChessWarrior7197',
#   'whoWon': 'black',
#   'date': '2022.04.12',
#   'time': '16:25:39'},
#  170: {'Hikaru': 'win',
#   'KazakhFighter04': 'timeout',
#   'black': 'Hikaru',
#   'white': 'KazakhFighter04',
#   'whoWon': 'black',
#   'date': '2022.04.12',
#   'time': '16:43:36'},
#  171: {'Hikaru': 'win',
#   'exoticprincess': 'checkmated',
#   'white': 'Hikaru',
#   'black': 'exoticprincess',
#   'whoWon': 'white',
#   'date': '2022.04.12',
#   'time': '16:52:50'},
#  172: {'Hikaru': 'repetition',
#   'wonderfultime': 'repetition',
#   'black': 'Hikaru',
#   'white': 'wonderfultime',
#   'whoWon': 'draw',
#   'date': '2022.04.12',
#   'time': '17:03:06'},
#  173: {'Hikaru': 'win',
#   'OhanyanEminChess': 'resigned',
#   'white': 'Hikaru',
#   'black': 'OhanyanEminChess',
#   'whoWon': 'white',
#   'date': '2022.04.12',
#   'time': '17:07:53'},
#  174: {'Hikaru': 'resigned',
#   'OhanyanEminChess': 'win',
#   'black': 'Hikaru',
#   'white': 'OhanyanEminChess',
#   'whoWon': 'white',
#   'date': '2022.04.12',
#   'time': '17:10:09'},
#  175: {'Hikaru': 'win',
#   'OhanyanEminChess': 'resigned',
#   'white': 'Hikaru',
#   'black': 'OhanyanEminChess',
#   'whoWon': 'white',
#   'date': '2022.04.12',
#   'time': '17:11:16'},
#  176: {'Hikaru': 'win',
#   'OhanyanEminChess': 'checkmated',
#   'black': 'Hikaru',
#   'white': 'OhanyanEminChess',
#   'whoWon': 'black',
#   'date': '2022.04.12',
#   'time': '17:13:18'},
#  177: {'Hikaru': 'win',
#   'OhanyanEminChess': 'resigned',
#   'white': 'Hikaru',
#   'black': 'OhanyanEminChess',
#   'whoWon': 'white',
#   'date': '2022.04.12',
#   'time': '17:14:40'},
#  178: {'Hikaru': 'win',
#   'OhanyanEminChess': 'resigned',
#   'black': 'Hikaru',
#   'white': 'OhanyanEminChess',
#   'whoWon': 'black',
#   'date': '2022.04.12',
#   'time': '17:16:25'},
#  179: {'Hikaru': 'win',
#   'OhanyanEminChess': 'resigned',
#   'white': 'Hikaru',
#   'black': 'OhanyanEminChess',
#   'whoWon': 'white',
#   'date': '2022.04.12',
#   'time': '17:17:16'},
#  180: {'Hikaru': 'timeout',
#   'OhanyanEminChess': 'win',
#   'black': 'Hikaru',
#   'white': 'OhanyanEminChess',
#   'whoWon': 'white',
#   'date': '2022.04.12',
#   'time': '17:19:33'},
#  181: {'Hikaru': 'win',
#   'OhanyanEminChess': 'resigned',
#   'white': 'Hikaru',
#   'black': 'OhanyanEminChess',
#   'whoWon': 'white',
#   'date': '2022.04.12',
#   'time': '17:21:02'},
#  182: {'Hikaru': 'win',
#   'OhanyanEminChess': 'resigned',
#   'black': 'Hikaru',
#   'white': 'OhanyanEminChess',
#   'whoWon': 'black',
#   'date': '2022.04.12',
#   'time': '17:22:32'},
#  183: {'Hikaru': 'win',
#   'OhanyanEminChess': 'resigned',
#   'white': 'Hikaru',
#   'black': 'OhanyanEminChess',
#   'whoWon': 'white',
#   'date': '2022.04.12',
#   'time': '17:24:41'},
#  184: {'Hikaru': 'win',
#   'OhanyanEminChess': 'timeout',
#   'black': 'Hikaru',
#   'white': 'OhanyanEminChess',
#   'whoWon': 'black',
#   'date': '2022.04.12',
#   'time': '17:27:00'},
#  185: {'Hikaru': 'win',
#   'OhanyanEminChess': 'resigned',
#   'white': 'Hikaru',
#   'black': 'OhanyanEminChess',
#   'whoWon': 'white',
#   'date': '2022.04.12',
#   'time': '17:28:12'},
#  186: {'Hikaru': 'win',
#   'OhanyanEminChess': 'resigned',
#   'black': 'Hikaru',
#   'white': 'OhanyanEminChess',
#   'whoWon': 'black',
#   'date': '2022.04.12',
#   'time': '17:29:23'},
#  187: {'Hikaru': 'resigned',
#   'OhanyanEminChess': 'win',
#   'white': 'Hikaru',
#   'black': 'OhanyanEminChess',
#   'whoWon': 'black',
#   'date': '2022.04.12',
#   'time': '17:31:26'},
#  188: {'Hikaru': 'resigned',
#   'OhanyanEminChess': 'win',
#   'black': 'Hikaru',
#   'white': 'OhanyanEminChess',
#   'whoWon': 'white',
#   'date': '2022.04.12',
#   'time': '17:33:44'},
#  189: {'Hikaru': 'win',
#   'OhanyanEminChess': 'resigned',
#   'white': 'Hikaru',
#   'black': 'OhanyanEminChess',
#   'whoWon': 'white',
#   'date': '2022.04.12',
#   'time': '17:35:03'},
#  190: {'Hikaru': 'win',
#   'OhanyanEminChess': 'resigned',
#   'black': 'Hikaru',
#   'white': 'OhanyanEminChess',
#   'whoWon': 'black',
#   'date': '2022.04.12',
#   'time': '17:36:33'},
#  191: {'Hikaru': 'win',
#   'OhanyanEminChess': 'resigned',
#   'white': 'Hikaru',
#   'black': 'OhanyanEminChess',
#   'whoWon': 'white',
#   'date': '2022.04.12',
#   'time': '17:38:17'},
#  192: {'Hikaru': 'win',
#   'OhanyanEminChess': 'timeout',
#   'black': 'Hikaru',
#   'white': 'OhanyanEminChess',
#   'whoWon': 'black',
#   'date': '2022.04.12',
#   'time': '17:40:30'},
#  193: {'Hikaru': 'win',
#   'CM_rui': 'resigned',
#   'black': 'Hikaru',
#   'white': 'CM_rui',
#   'whoWon': 'black',
#   'date': '2022.04.12',
#   'time': '21:05:48'},
#  194: {'Hikaru': 'win',
#   'azikom': 'timeout',
#   'white': 'Hikaru',
#   'black': 'azikom',
#   'whoWon': 'white',
#   'date': '2022.04.12',
#   'time': '21:17:26'},
#  195: {'Hikaru': 'win',
#   'KhazarBabazada007': 'resigned',
#   'black': 'Hikaru',
#   'white': 'KhazarBabazada007',
#   'whoWon': 'black',
#   'date': '2022.04.12',
#   'time': '21:28:59'},
#  196: {'Hikaru': 'win',
#   'Beca95': 'resigned',
#   'white': 'Hikaru',
#   'black': 'Beca95',
#   'whoWon': 'white',
#   'date': '2022.04.12',
#   'time': '21:37:29'},
#  197: {'Hikaru': 'timeout',
#   'Hrant_ChessMood': 'win',
#   'black': 'Hikaru',
#   'white': 'Hrant_ChessMood',
#   'whoWon': 'white',
#   'date': '2022.04.12',
#   'time': '21:57:01'},
#  198: {'Hikaru': 'win',
#   'honestgames': 'checkmated',
#   'white': 'Hikaru',
#   'black': 'honestgames',
#   'whoWon': 'white',
#   'date': '2022.04.12',
#   'time': '22:03:50'},
#  199: {'Hikaru': 'win',
#   'Zhigalko_Sergei': 'resigned',
#   'black': 'Hikaru',
#   'white': 'Zhigalko_Sergei',
#   'whoWon': 'black',
#   'date': '2022.04.12',
#   'time': '22:14:12'},
#  200: {'Hikaru': 'win',
#   'FabianoCaruana': 'resigned',
#   'white': 'Hikaru',
#   'black': 'FabianoCaruana',
#   'whoWon': 'white',
#   'date': '2022.04.12',
#   'time': '22:24:46'},
#  201: {'Hikaru': 'win',
#   'Korchmar_Vasiliy': 'timeout',
#   'white': 'Hikaru',
#   'black': 'Korchmar_Vasiliy',
#   'whoWon': 'white',
#   'date': '2022.04.12',
#   'time': '22:39:36'},
#  202: {'Hikaru': 'win',
#   'AryanTari': 'timeout',
#   'black': 'Hikaru',
#   'white': 'AryanTari',
#   'whoWon': 'black',
#   'date': '2022.04.12',
#   'time': '22:50:43'},
#  203: {'Hikaru': 'win',
#   'FairChess_on_YouTube': 'checkmated',
#   'white': 'Hikaru',
#   'black': 'FairChess_on_YouTube',
#   'whoWon': 'white',
#   'date': '2022.04.12',
#   'time': '23:00:41'},
#  204: {'Hikaru': 'win',
#   'Oleksandr_Bortnyk': 'resigned',
#   'white': 'Hikaru',
#   'black': 'Oleksandr_Bortnyk',
#   'whoWon': 'white',
#   'date': '2022.04.13',
#   'time': '16:03:47'},
#  205: {'Hikaru': 'win',
#   'GolovinLeonid': 'timeout',
#   'black': 'Hikaru',
#   'white': 'GolovinLeonid',
#   'whoWon': 'black',
#   'date': '2022.04.13',
#   'time': '16:09:10'},
#  206: {'Hikaru': 'resigned',
#   'Yusup_Atabayev': 'win',
#   'black': 'Hikaru',
#   'white': 'Yusup_Atabayev',
#   'whoWon': 'white',
#   'date': '2022.04.13',
#   'time': '16:14:53'},
#  207: {'Hikaru': 'win',
#   'Shuvalov': 'timeout',
#   'black': 'Hikaru',
#   'white': 'Shuvalov',
#   'whoWon': 'black',
#   'date': '2022.04.13',
#   'time': '16:20:19'},
#  208: {'Hikaru': 'win',
#   'TigrVShlyape': 'resigned',
#   'white': 'Hikaru',
#   'black': 'TigrVShlyape',
#   'whoWon': 'white',
#   'date': '2022.04.13',
#   'time': '16:22:52'},
#  209: {'Hikaru': 'win',
#   'ArtemChessRU': 'resigned',
#   'white': 'Hikaru',
#   'black': 'ArtemChessRU',
#   'whoWon': 'white',
#   'date': '2022.04.13',
#   'time': '16:27:04'},
#  210: {'Hikaru': 'win',
#   'TigrVShlyape': 'timeout',
#   'black': 'Hikaru',
#   'white': 'TigrVShlyape',
#   'whoWon': 'black',
#   'date': '2022.04.13',
#   'time': '16:32:36'},
#  211: {'Hikaru': 'win',
#   'ErikRonka': 'resigned',
#   'white': 'Hikaru',
#   'black': 'ErikRonka',
#   'whoWon': 'white',
#   'date': '2022.04.13',
#   'time': '16:34:58'},
#  212: {'Hikaru': 'win',
#   'TigrVShlyape': 'timeout',
#   'white': 'Hikaru',
#   'black': 'TigrVShlyape',
#   'whoWon': 'white',
#   'date': '2022.04.13',
#   'time': '16:41:10'},
#  213: {'Hikaru': 'win',
#   'DragonB70': 'resigned',
#   'black': 'Hikaru',
#   'white': 'DragonB70',
#   'whoWon': 'black',
#   'date': '2022.04.13',
#   'time': '16:44:52'},
#  214: {'Hikaru': 'win',
#   'christian_mendoza14': 'resigned',
#   'black': 'Hikaru',
#   'white': 'christian_mendoza14',
#   'whoWon': 'black',
#   'date': '2022.04.13',
#   'time': '16:49:01'},
#  215: {'Hikaru': 'win',
#   'Sattarov_Bobur': 'resigned',
#   'white': 'Hikaru',
#   'black': 'Sattarov_Bobur',
#   'whoWon': 'white',
#   'date': '2022.04.13',
#   'time': '16:53:12'},
#  216: {'Hikaru': 'win',
#   'Zhigalko_Sergei': 'resigned',
#   'white': 'Hikaru',
#   'black': 'Zhigalko_Sergei',
#   'whoWon': 'white',
#   'date': '2022.04.13',
#   'time': '16:58:15'},
#  217: {'Hikaru': 'win',
#   'Blitzstream': 'checkmated',
#   'black': 'Hikaru',
#   'white': 'Blitzstream',
#   'whoWon': 'black',
#   'date': '2022.04.13',
#   'time': '17:00:54'},
#  218: {'Hikaru': 'win',
#   'MaxiNimzo': 'resigned',
#   'black': 'Hikaru',
#   'white': 'MaxiNimzo',
#   'whoWon': 'black',
#   'date': '2022.04.13',
#   'time': '17:05:48'},
#  219: {'Hikaru': 'win',
#   'wonderfultime': 'resigned',
#   'white': 'Hikaru',
#   'black': 'wonderfultime',
#   'whoWon': 'white',
#   'date': '2022.04.13',
#   'time': '17:12:09'},
#  220: {'Hikaru': 'win',
#   'OhanyanEminChess': 'resigned',
#   'white': 'Hikaru',
#   'black': 'OhanyanEminChess',
#   'whoWon': 'white',
#   'date': '2022.04.13',
#   'time': '17:15:37'},
#  221: {'Hikaru': 'win',
#   'jcibarra': 'resigned',
#   'white': 'Hikaru',
#   'black': 'jcibarra',
#   'whoWon': 'white',
#   'date': '2022.04.13',
#   'time': '17:20:29'},
#  222: {'Hikaru': 'win',
#   'Blitzstream': 'resigned',
#   'white': 'Hikaru',
#   'black': 'Blitzstream',
#   'whoWon': 'white',
#   'date': '2022.04.13',
#   'time': '17:22:38'},
#  223: {'Hikaru': 'win',
#   'Jet_Black1': 'resigned',
#   'black': 'Hikaru',
#   'white': 'Jet_Black1',
#   'whoWon': 'black',
#   'date': '2022.04.13',
#   'time': '17:25:22'},
#  224: {'Hikaru': 'win',
#   'Chessking2007Sh': 'resigned',
#   'black': 'Hikaru',
#   'white': 'Chessking2007Sh',
#   'whoWon': 'black',
#   'date': '2022.04.13',
#   'time': '17:30:54'},
#  225: {'Hikaru': 'win',
#   'AtabayevSaparmyrat': 'checkmated',
#   'black': 'Hikaru',
#   'white': 'AtabayevSaparmyrat',
#   'whoWon': 'black',
#   'date': '2022.04.13',
#   'time': '17:36:00'},
#  226: {'Hikaru': 'win',
#   'viktorskliarov': 'resigned',
#   'white': 'Hikaru',
#   'black': 'viktorskliarov',
#   'whoWon': 'white',
#   'date': '2022.04.13',
#   'time': '17:40:35'},
#  227: {'Hikaru': 'win',
#   'JimDiGrease': 'resigned',
#   'black': 'Hikaru',
#   'white': 'JimDiGrease',
#   'whoWon': 'black',
#   'date': '2022.04.13',
#   'time': '17:45:42'},
#  228: {'Hikaru': 'win',
#   'Oleksandr_Bortnyk': 'timeout',
#   'black': 'Hikaru',
#   'white': 'Oleksandr_Bortnyk',
#   'whoWon': 'black',
#   'date': '2022.04.13',
#   'time': '17:52:06'},
#  229: {'Hikaru': 'win',
#   'LoLsuppAddict': 'checkmated',
#   'white': 'Hikaru',
#   'black': 'LoLsuppAddict',
#   'whoWon': 'white',
#   'date': '2022.04.13',
#   'time': '18:21:57'},
#  230: {'Hikaru': 'win',
#   'LoLsuppAddict': 'resigned',
#   'black': 'Hikaru',
#   'white': 'LoLsuppAddict',
#   'whoWon': 'black',
#   'date': '2022.04.13',
#   'time': '18:25:51'},
#  231: {'Hikaru': 'win',
#   'moro182': 'resigned',
#   'white': 'Hikaru',
#   'black': 'moro182',
#   'whoWon': 'white',
#   'date': '2022.04.13',
#   'time': '18:40:22'},
#  232: {'Hikaru': 'win',
#   'moro182': 'resigned',
#   'black': 'Hikaru',
#   'white': 'moro182',
#   'whoWon': 'black',
#   'date': '2022.04.13',
#   'time': '18:46:05'},
#  233: {'Hikaru': 'win',
#   'Jospem': 'timeout',
#   'white': 'Hikaru',
#   'black': 'Jospem',
#   'whoWon': 'white',
#   'date': '2022.04.13',
#   'time': '19:04:54'},
#  234: {'Hikaru': 'win',
#   'Jospem': 'resigned',
#   'black': 'Hikaru',
#   'white': 'Jospem',
#   'whoWon': 'black',
#   'date': '2022.04.13',
#   'time': '19:10:16'},
#  235: {'Hikaru': 'win',
#   'Oleksandr_Bortnyk': 'timeout',
#   'white': 'Hikaru',
#   'black': 'Oleksandr_Bortnyk',
#   'whoWon': 'white',
#   'date': '2022.04.13',
#   'time': '19:33:32'},
#  236: {'Hikaru': 'win',
#   'Oleksandr_Bortnyk': 'resigned',
#   'black': 'Hikaru',
#   'white': 'Oleksandr_Bortnyk',
#   'whoWon': 'black',
#   'date': '2022.04.13',
#   'time': '19:37:34'},
#  237: {'Hikaru': 'insufficient',
#   'Oleksandr_Bortnyk': 'insufficient',
#   'white': 'Hikaru',
#   'black': 'Oleksandr_Bortnyk',
#   'date': '2022.04.13',
#   'time': '19:43:07'},
#  238: {'Hikaru': 'win',
#   'Oleksandr_Bortnyk': 'timeout',
#   'black': 'Hikaru',
#   'white': 'Oleksandr_Bortnyk',
#   'whoWon': 'black',
#   'date': '2022.04.13',
#   'time': '19:48:55'},
#  239: {'Hikaru': 'win',
#   'Konavets': 'timeout',
#   'black': 'Hikaru',
#   'white': 'Konavets',
#   'whoWon': 'black',
#   'date': '2022.04.16',
#   'time': '16:17:55'},
#  240: {'Hikaru': 'win',
#   'Andreikka': 'resigned',
#   'white': 'Hikaru',
#   'black': 'Andreikka',
#   'whoWon': 'white',
#   'date': '2022.04.16',
#   'time': '16:39:17'},
#  241: {'Hikaru': 'repetition',
#   'FabianoCaruana': 'repetition',
#   'black': 'Hikaru',
#   'white': 'FabianoCaruana',
#   'whoWon': 'draw',
#   'date': '2022.04.16',
#   'time': '16:42:19'},
#  242: {'Hikaru': 'win',
#   'FairChess_on_YouTube': 'resigned',
#   'white': 'Hikaru',
#   'black': 'FairChess_on_YouTube',
#   'whoWon': 'white',
#   'date': '2022.04.16',
#   'time': '17:22:15'},
#  243: {'Hikaru': 'win',
#   'LevonAronian': 'resigned',
#   'black': 'Hikaru',
#   'white': 'LevonAronian',
#   'whoWon': 'black',
#   'date': '2022.04.16',
#   'time': '17:45:25'},
#  244: {'Hikaru': 'win',
#   'jefferyx': 'resigned',
#   'white': 'Hikaru',
#   'black': 'jefferyx',
#   'whoWon': 'white',
#   'date': '2022.04.16',
#   'time': '18:06:43'},
#  245: {'Hikaru': 'repetition',
#   'Jospem': 'repetition',
#   'black': 'Hikaru',
#   'white': 'Jospem',
#   'whoWon': 'draw',
#   'date': '2022.04.16',
#   'time': '18:12:45'},
#  246: {'Hikaru': 'repetition',
#   'AnishGiri': 'repetition',
#   'white': 'Hikaru',
#   'black': 'AnishGiri',
#   'whoWon': 'draw',
#   'date': '2022.04.16',
#   'time': '18:34:36'},
#  247: {'Hikaru': 'repetition',
#   'Grischuk': 'repetition',
#   'black': 'Hikaru',
#   'white': 'Grischuk',
#   'whoWon': 'draw',
#   'date': '2022.04.16',
#   'time': '18:56:32'},
#  248: {'Hikaru': 'win',
#   'jefferyx': 'resigned',
#   'white': 'Hikaru',
#   'black': 'jefferyx',
#   'whoWon': 'white',
#   'date': '2022.04.17',
#   'time': '16:21:52'},
#  249: {'Hikaru': 'resigned',
#   'Grischuk': 'win',
#   'white': 'Hikaru',
#   'black': 'Grischuk',
#   'whoWon': 'black',
#   'date': '2022.04.17',
#   'time': '18:45:14'},
#  250: {'Hikaru': 'win',
#   'sosadaboot': 'timeout',
#   'black': 'Hikaru',
#   'white': 'sosadaboot',
#   'whoWon': 'black',
#   'date': '2022.04.18',
#   'time': '12:57:54'},
#  251: {'Hikaru': 'win',
#   'sosadaboot': 'resigned',
#   'white': 'Hikaru',
#   'black': 'sosadaboot',
#   'whoWon': 'white',
#   'date': '2022.04.18',
#   'time': '13:03:06'},
#  252: {'Hikaru': 'win',
#   'sosadaboot': 'resigned',
#   'black': 'Hikaru',
#   'white': 'sosadaboot',
#   'whoWon': 'black',
#   'date': '2022.04.18',
#   'time': '13:06:47'},
#  253: {'Hikaru': 'win',
#   'sosadaboot': 'resigned',
#   'white': 'Hikaru',
#   'black': 'sosadaboot',
#   'whoWon': 'white',
#   'date': '2022.04.18',
#   'time': '13:11:56'},
#  254: {'Hikaru': 'win',
#   'sosadaboot': 'resigned',
#   'black': 'Hikaru',
#   'white': 'sosadaboot',
#   'whoWon': 'black',
#   'date': '2022.04.18',
#   'time': '13:17:16'},
#  255: {'Hikaru': 'win',
#   'sosadaboot': 'resigned',
#   'white': 'Hikaru',
#   'black': 'sosadaboot',
#   'whoWon': 'white',
#   'date': '2022.04.18',
#   'time': '13:21:31'},
#  256: {'Hikaru': 'win',
#   'sosadaboot': 'resigned',
#   'black': 'Hikaru',
#   'white': 'sosadaboot',
#   'whoWon': 'black',
#   'date': '2022.04.18',
#   'time': '13:26:49'},
#  257: {'Hikaru': 'win',
#   'sosadaboot': 'resigned',
#   'white': 'Hikaru',
#   'black': 'sosadaboot',
#   'whoWon': 'white',
#   'date': '2022.04.18',
#   'time': '13:32:13'},
#  258: {'Hikaru': 'checkmated',
#   'sosadaboot': 'win',
#   'black': 'Hikaru',
#   'white': 'sosadaboot',
#   'whoWon': 'white',
#   'date': '2022.04.18',
#   'time': '13:38:20'},
#  259: {'Hikaru': 'win',
#   'sosadaboot': 'resigned',
#   'white': 'Hikaru',
#   'black': 'sosadaboot',
#   'whoWon': 'white',
#   'date': '2022.04.18',
#   'time': '13:43:33'},
#  260: {'Hikaru': 'win',
#   'sosadaboot': 'checkmated',
#   'black': 'Hikaru',
#   'white': 'sosadaboot',
#   'whoWon': 'black',
#   'date': '2022.04.18',
#   'time': '13:49:42'},
#  261: {'Hikaru': 'win',
#   'Airquake': 'timeout',
#   'black': 'Hikaru',
#   'white': 'Airquake',
#   'whoWon': 'black',
#   'date': '2022.04.19',
#   'time': '15:06:25'},
#  262: {'Hikaru': 'win',
#   'azikom': 'checkmated',
#   'white': 'Hikaru',
#   'black': 'azikom',
#   'whoWon': 'white',
#   'date': '2022.04.19',
#   'time': '15:17:20'},
#  263: {'Hikaru': 'win',
#   'Kezin_Roman': 'timeout',
#   'black': 'Hikaru',
#   'white': 'Kezin_Roman',
#   'whoWon': 'black',
#   'date': '2022.04.19',
#   'time': '15:25:37'},
#  264: {'Hikaru': 'win',
#   'OparinGrigoriy': 'resigned',
#   'white': 'Hikaru',
#   'black': 'OparinGrigoriy',
#   'whoWon': 'white',
#   'date': '2022.04.19',
#   'time': '15:35:38'},
#  265: {'Hikaru': 'win',
#   'Zhigalko_Sergei': 'timeout',
#   'black': 'Hikaru',
#   'white': 'Zhigalko_Sergei',
#   'whoWon': 'black',
#   'date': '2022.04.19',
#   'time': '15:56:23'},
#  266: {'Hikaru': 'win',
#   'BilodeauA': 'resigned',
#   'black': 'Hikaru',
#   'white': 'BilodeauA',
#   'whoWon': 'black',
#   'date': '2022.04.19',
#   'time': '16:07:26'},
#  267: {'Hikaru': 'win',
#   'Bigfish1995': 'resigned',
#   'white': 'Hikaru',
#   'black': 'Bigfish1995',
#   'whoWon': 'white',
#   'date': '2022.04.19',
#   'time': '16:17:54'},
#  268: {'Hikaru': 'resigned',
#   'FairChess_on_YouTube': 'win',
#   'black': 'Hikaru',
#   'white': 'FairChess_on_YouTube',
#   'whoWon': 'white',
#   'date': '2022.04.19',
#   'time': '16:27:50'},
#  269: {'Hikaru': 'win',
#   'Oleksandr_Bortnyk': 'timeout',
#   'white': 'Hikaru',
#   'black': 'Oleksandr_Bortnyk',
#   'whoWon': 'white',
#   'date': '2022.04.19',
#   'time': '16:42:57'},
#  270: {'Hikaru': 'insufficient',
#   'rasmussvane': 'insufficient',
#   'black': 'Hikaru',
#   'white': 'rasmussvane',
#   'date': '2022.04.19',
#   'time': '16:53:52'},
#  271: {'Hikaru': 'win',
#   'wonderfultime': 'timeout',
#   'white': 'Hikaru',
#   'black': 'wonderfultime',
#   'whoWon': 'white',
#   'date': '2022.04.19',
#   'time': '17:03:27'},
#  272: {'Hikaru': 'win',
#   'yavrukurt40': 'timeout',
#   'white': 'Hikaru',
#   'black': 'yavrukurt40',
#   'whoWon': 'white',
#   'date': '2022.04.19',
#   'time': '18:44:10'},
#  273: {'Hikaru': 'win',
#   'yavrukurt40': 'resigned',
#   'black': 'Hikaru',
#   'white': 'yavrukurt40',
#   'whoWon': 'black',
#   'date': '2022.04.19',
#   'time': '18:48:20'},
#  274: {'Hikaru': 'win',
#   'yavrukurt40': 'resigned',
#   'white': 'Hikaru',
#   'black': 'yavrukurt40',
#   'whoWon': 'white',
#   'date': '2022.04.19',
#   'time': '18:53:02'},
#  275: {'Hikaru': 'win',
#   'yavrukurt40': 'resigned',
#   'black': 'Hikaru',
#   'white': 'yavrukurt40',
#   'whoWon': 'black',
#   'date': '2022.04.19',
#   'time': '18:56:54'},
#  276: {'Hikaru': 'win',
#   'yavrukurt40': 'resigned',
#   'white': 'Hikaru',
#   'black': 'yavrukurt40',
#   'whoWon': 'white',
#   'date': '2022.04.19',
#   'time': '19:00:16'},
#  277: {'Hikaru': 'win',
#   'yavrukurt40': 'resigned',
#   'black': 'Hikaru',
#   'white': 'yavrukurt40',
#   'whoWon': 'black',
#   'date': '2022.04.19',
#   'time': '19:05:57'},
#  278: {'Hikaru': 'win',
#   'PlotnikovPavel': 'timeout',
#   'black': 'Hikaru',
#   'white': 'PlotnikovPavel',
#   'whoWon': 'black',
#   'date': '2022.04.19',
#   'time': '21:06:49'},
#  279: {'Hikaru': 'win',
#   'tdf98pantani': 'resigned',
#   'white': 'Hikaru',
#   'black': 'tdf98pantani',
#   'whoWon': 'white',
#   'date': '2022.04.19',
#   'time': '21:16:06'},
#  280: {'Hikaru': 'resigned',
#   'KhazarBabazada007': 'win',
#   'black': 'Hikaru',
#   'white': 'KhazarBabazada007',
#   'whoWon': 'white',
#   'date': '2022.04.19',
#   'time': '21:27:21'},
#  281: {'Hikaru': 'win',
#   'bazar-wokzal': 'checkmated',
#   'white': 'Hikaru',
#   'black': 'bazar-wokzal',
#   'whoWon': 'white',
#   'date': '2022.04.19',
#   'time': '21:35:53'},
#  282: {'Hikaru': 'win',
#   'hulkmania8949': 'resigned',
#   'white': 'Hikaru',
#   'black': 'hulkmania8949',
#   'whoWon': 'white',
#   'date': '2022.04.19',
#   'time': '21:51:51'},
#  283: {'Hikaru': 'win',
#   'Fandorine': 'resigned',
#   'black': 'Hikaru',
# ...
#   'FormerProdigy': 'repetition',
#   'white': 'Hikaru',
#   'black': 'FormerProdigy',
#   'whoWon': 'draw',
#   'date': '2022.04.23',
#   'time': '18:56:15'},
#  365: {'Hikaru': 'win',
#   'BrandonJacobson': 'resigned',
#   'white': 'Hikaru',
#   'black': 'BrandonJacobson',
#   'whoWon': 'white',
#   'date': '2022.04.23',
#   'time': '21:25:54'},
#  366: {'Hikaru': 'win',
#   'BrandonJacobson': 'resigned',
#   'black': 'Hikaru',
#   'white': 'BrandonJacobson',
#   'whoWon': 'black',
#   'date': '2022.04.23',
#   'time': '21:31:38'},
#  367: {'Hikaru': 'win',
#   'BrandonJacobson': 'resigned',
#   'white': 'Hikaru',
#   'black': 'BrandonJacobson',
#   'whoWon': 'white',
#   'date': '2022.04.23',
#   'time': '21:36:14'},
#  368: {'Hikaru': 'win',
#   'BrandonJacobson': 'resigned',
#   'black': 'Hikaru',
#   'white': 'BrandonJacobson',
#   'whoWon': 'black',
#   'date': '2022.04.23',
#   'time': '21:41:17'},
#  369: {'Hikaru': 'win',
#   'BrandonJacobson': 'resigned',
#   'white': 'Hikaru',
#   'black': 'BrandonJacobson',
#   'whoWon': 'white',
#   'date': '2022.04.23',
#   'time': '21:45:02'},
#  370: {'Hikaru': 'win',
#   'BrandonJacobson': 'resigned',
#   'black': 'Hikaru',
#   'white': 'BrandonJacobson',
#   'whoWon': 'black',
#   'date': '2022.04.23',
#   'time': '21:50:52'},
#  371: {'Hikaru': 'win',
#   'Jospem': 'timeout',
#   'white': 'Hikaru',
#   'black': 'Jospem',
#   'whoWon': 'white',
#   'date': '2022.04.24',
#   'time': '16:21:39'},
#  372: {'Hikaru': 'resigned',
#   'Andreikka': 'win',
#   'white': 'Hikaru',
#   'black': 'Andreikka',
#   'whoWon': 'black',
#   'date': '2022.04.24',
#   'time': '18:22:43'},
#  373: {'Hikaru': 'win',
#   'alexrustemov': 'timeout',
#   'black': 'Hikaru',
#   'white': 'alexrustemov',
#   'whoWon': 'black',
#   'date': '2022.04.25',
#   'time': '19:07:25'},
#  374: {'Hikaru': 'repetition',
#   'alexrustemov': 'repetition',
#   'white': 'Hikaru',
#   'black': 'alexrustemov',
#   'whoWon': 'draw',
#   'date': '2022.04.25',
#   'time': '19:12:23'},
#  375: {'Hikaru': 'win',
#   'alexrustemov': 'timeout',
#   'black': 'Hikaru',
#   'white': 'alexrustemov',
#   'whoWon': 'black',
#   'date': '2022.04.25',
#   'time': '19:17:18'},
#  376: {'Hikaru': 'win',
#   'alexrustemov': 'resigned',
#   'white': 'Hikaru',
#   'black': 'alexrustemov',
#   'whoWon': 'white',
#   'date': '2022.04.25',
#   'time': '19:22:09'},
#  377: {'Hikaru': 'win',
#   'alexrustemov': 'resigned',
#   'black': 'Hikaru',
#   'white': 'alexrustemov',
#   'whoWon': 'black',
#   'date': '2022.04.25',
#   'time': '19:25:14'},
#  378: {'Hikaru': 'win',
#   'alexrustemov': 'timeout',
#   'white': 'Hikaru',
#   'black': 'alexrustemov',
#   'whoWon': 'white',
#   'date': '2022.04.25',
#   'time': '19:30:37'},
#  379: {'Hikaru': 'win',
#   'Mykola-Bortnyk': 'resigned',
#   'black': 'Hikaru',
#   'white': 'Mykola-Bortnyk',
#   'whoWon': 'black',
#   'date': '2022.04.25',
#   'time': '19:36:12'},
#  380: {'Hikaru': 'checkmated',
#   'Mykola-Bortnyk': 'win',
#   'white': 'Hikaru',
#   'black': 'Mykola-Bortnyk',
#   'whoWon': 'black',
#   'date': '2022.04.25',
#   'time': '19:42:14'},
#  381: {'Hikaru': 'repetition',
#   'Mykola-Bortnyk': 'repetition',
#   'black': 'Hikaru',
#   'white': 'Mykola-Bortnyk',
#   'whoWon': 'draw',
#   'date': '2022.04.25',
#   'time': '19:46:43'},
#  382: {'Hikaru': 'win',
#   'Mykola-Bortnyk': 'resigned',
#   'white': 'Hikaru',
#   'black': 'Mykola-Bortnyk',
#   'whoWon': 'white',
#   'date': '2022.04.25',
#   'time': '19:52:22'},
#  383: {'Hikaru': 'repetition',
#   'Mykola-Bortnyk': 'repetition',
#   'black': 'Hikaru',
#   'white': 'Mykola-Bortnyk',
#   'whoWon': 'draw',
#   'date': '2022.04.25',
#   'time': '19:57:48'},
#  384: {'Hikaru': 'win',
#   'Mykola-Bortnyk': 'timeout',
#   'white': 'Hikaru',
#   'black': 'Mykola-Bortnyk',
#   'whoWon': 'white',
#   'date': '2022.04.25',
#   'time': '20:03:49'},
#  385: {'Hikaru': 'resigned',
#   'Mykola-Bortnyk': 'win',
#   'black': 'Hikaru',
#   'white': 'Mykola-Bortnyk',
#   'whoWon': 'white',
#   'date': '2022.04.25',
#   'time': '20:06:30'},
#  386: {'Hikaru': '50move',
#   'Mykola-Bortnyk': '50move',
#   'white': 'Hikaru',
#   'black': 'Mykola-Bortnyk',
#   'date': '2022.04.25',
#   'time': '20:12:18'},
#  387: {'Hikaru': 'win',
#   'Mykola-Bortnyk': 'timeout',
#   'black': 'Hikaru',
#   'white': 'Mykola-Bortnyk',
#   'whoWon': 'black',
#   'date': '2022.04.25',
#   'time': '20:18:27'},
#  388: {'Hikaru': 'win',
#   'Mykola-Bortnyk': 'resigned',
#   'white': 'Hikaru',
#   'black': 'Mykola-Bortnyk',
#   'whoWon': 'white',
#   'date': '2022.04.25',
#   'time': '20:22:50'},
#  389: {'Hikaru': 'win',
#   'Mykola-Bortnyk': 'resigned',
#   'black': 'Hikaru',
#   'white': 'Mykola-Bortnyk',
#   'whoWon': 'black',
#   'date': '2022.04.25',
#   'time': '20:26:43'},
#  390: {'Hikaru': 'win',
#   'Mykola-Bortnyk': 'resigned',
#   'white': 'Hikaru',
#   'black': 'Mykola-Bortnyk',
#   'whoWon': 'white',
#   'date': '2022.04.25',
#   'time': '20:30:03'},
#  391: {'Hikaru': 'win',
#   'SantoBlue': 'resigned',
#   'black': 'Hikaru',
#   'white': 'SantoBlue',
#   'whoWon': 'black',
#   'date': '2022.04.26',
#   'time': '14:23:44'},
#  392: {'Hikaru': 'win',
#   'SantoBlue': 'resigned',
#   'white': 'Hikaru',
#   'black': 'SantoBlue',
#   'whoWon': 'white',
#   'date': '2022.04.26',
#   'time': '14:29:24'},
#  393: {'Hikaru': 'win',
#   'SantoBlue': 'resigned',
#   'black': 'Hikaru',
#   'white': 'SantoBlue',
#   'whoWon': 'black',
#   'date': '2022.04.26',
#   'time': '14:33:25'},
#  394: {'Hikaru': 'win',
#   'SantoBlue': 'resigned',
#   'white': 'Hikaru',
#   'black': 'SantoBlue',
#   'whoWon': 'white',
#   'date': '2022.04.26',
#   'time': '14:35:43'},
#  395: {'Hikaru': 'win',
#   'COCOLASTICOTTE': 'resigned',
#   'white': 'Hikaru',
#   'black': 'COCOLASTICOTTE',
#   'whoWon': 'white',
#   'date': '2022.04.26',
#   'time': '15:07:43'},
#  396: {'Hikaru': 'win',
#   'Leonid_Starozhilov': 'checkmated',
#   'black': 'Hikaru',
#   'white': 'Leonid_Starozhilov',
#   'whoWon': 'black',
#   'date': '2022.04.26',
#   'time': '15:15:34'},
#  397: {'Hikaru': 'win',
#   'Abund': 'resigned',
#   'white': 'Hikaru',
#   'black': 'Abund',
#   'whoWon': 'white',
#   'date': '2022.04.26',
#   'time': '15:24:31'},
#  398: {'Hikaru': 'win',
#   'Obsidian-Destroyer': 'resigned',
#   'white': 'Hikaru',
#   'black': 'Obsidian-Destroyer',
#   'whoWon': 'white',
#   'date': '2022.04.26',
#   'time': '15:40:31'},
#  399: {'Hikaru': 'win',
#   'rasmussvane': 'timeout',
#   'black': 'Hikaru',
#   'white': 'rasmussvane',
#   'whoWon': 'black',
#   'date': '2022.04.26',
#   'time': '15:55:24'},
#  400: {'Hikaru': 'repetition',
#   'DenLaz': 'repetition',
#   'white': 'Hikaru',
#   'black': 'DenLaz',
#   'whoWon': 'draw',
#   'date': '2022.04.26',
#   'time': '16:05:22'},
#  401: {'Hikaru': 'repetition',
#   'Andreikka': 'repetition',
#   'white': 'Hikaru',
#   'black': 'Andreikka',
#   'whoWon': 'draw',
#   'date': '2022.04.26',
#   'time': '16:15:37'},
#  402: {'Hikaru': 'win',
#   'Shankland': 'resigned',
#   'black': 'Hikaru',
#   'white': 'Shankland',
#   'whoWon': 'black',
#   'date': '2022.04.26',
#   'time': '16:23:31'},
#  403: {'Hikaru': 'win',
#   'BilodeauA': 'resigned',
#   'white': 'Hikaru',
#   'black': 'BilodeauA',
#   'whoWon': 'white',
#   'date': '2022.04.26',
#   'time': '16:38:58'},
#  404: {'Hikaru': 'win',
#   'Oleksandr_Bortnyk': 'resigned',
#   'black': 'Hikaru',
#   'white': 'Oleksandr_Bortnyk',
#   'whoWon': 'black',
#   'date': '2022.04.26',
#   'time': '16:48:49'},
#  405: {'Hikaru': 'win',
#   'Duhless': 'timeout',
#   'black': 'Hikaru',
#   'white': 'Duhless',
#   'whoWon': 'black',
#   'date': '2022.04.26',
#   'time': '16:59:52'},
#  406: {'Hikaru': 'win',
#   'Arigu07': 'resigned',
#   'white': 'Hikaru',
#   'black': 'Arigu07',
#   'whoWon': 'white',
#   'date': '2022.04.26',
#   'time': '21:06:09'},
#  407: {'Hikaru': 'win',
#   'GothamChess': 'resigned',
#   'black': 'Hikaru',
#   'white': 'GothamChess',
#   'whoWon': 'black',
#   'date': '2022.04.26',
#   'time': '21:15:15'},
#  408: {'Hikaru': 'win',
#   'ChessLover0108': 'resigned',
#   'white': 'Hikaru',
#   'black': 'ChessLover0108',
#   'whoWon': 'white',
#   'date': '2022.04.26',
#   'time': '21:28:19'},
#  409: {'Hikaru': 'insufficient',
#   'Msb2': 'insufficient',
#   'black': 'Hikaru',
#   'white': 'Msb2',
#   'date': '2022.04.26',
#   'time': '21:38:17'},
#  410: {'Hikaru': 'win',
#   'GM_dmitrij': 'timeout',
#   'black': 'Hikaru',
#   'white': 'GM_dmitrij',
#   'whoWon': 'black',
#   'date': '2022.04.26',
#   'time': '21:55:26'},
#  411: {'Hikaru': 'repetition',
#   'K_A_S_T_O_R': 'repetition',
#   'white': 'Hikaru',
#   'black': 'K_A_S_T_O_R',
#   'whoWon': 'draw',
#   'date': '2022.04.26',
#   'time': '22:03:48'},
#  412: {'Hikaru': 'win',
#   'AryanTari': 'resigned',
#   'black': 'Hikaru',
#   'white': 'AryanTari',
#   'whoWon': 'black',
#   'date': '2022.04.26',
#   'time': '22:11:49'},
#  413: {'Hikaru': 'resigned',
#   'Oleksandr_Bortnyk': 'win',
#   'white': 'Hikaru',
#   'black': 'Oleksandr_Bortnyk',
#   'whoWon': 'black',
#   'date': '2022.04.26',
#   'time': '22:24:34'},
#  414: {'Hikaru': 'win',
#   'mishanick': 'checkmated',
#   'black': 'Hikaru',
#   'white': 'mishanick',
#   'whoWon': 'black',
#   'date': '2022.04.26',
#   'time': '22:40:56'},
#  415: {'Hikaru': 'win',
#   'Bigfish1995': 'timeout',
#   'white': 'Hikaru',
#   'black': 'Bigfish1995',
#   'whoWon': 'white',
#   'date': '2022.04.26',
#   'time': '22:50:33'},
#  416: {'Hikaru': 'resigned',
#   'exoticprincess': 'win',
#   'white': 'Hikaru',
#   'black': 'exoticprincess',
#   'whoWon': 'black',
#   'date': '2022.04.26',
#   'time': '23:00:33'},
#  417: {'Hikaru': 'win',
#   'Oleksandr_Bortnyk': 'resigned',
#   'black': 'Hikaru',
#   'white': 'Oleksandr_Bortnyk',
#   'whoWon': 'black',
#   'date': '2022.04.27',
#   'time': '16:05:03'},
#  418: {'Hikaru': 'win',
#   'wonderfultime': 'timeout',
#   'black': 'Hikaru',
#   'white': 'wonderfultime',
#   'whoWon': 'black',
#   'date': '2022.04.27',
#   'time': '16:10:45'},
#  419: {'Hikaru': 'win',
#   'orangutan19': 'resigned',
#   'white': 'Hikaru',
#   'black': 'orangutan19',
#   'whoWon': 'white',
#   'date': '2022.04.27',
#   'time': '16:15:07'},
#  420: {'Hikaru': 'win',
#   'GyurjinyanValter': 'resigned',
#   'black': 'Hikaru',
#   'white': 'GyurjinyanValter',
#   'whoWon': 'black',
#   'date': '2022.04.27',
#   'time': '16:19:59'},
#  421: {'Hikaru': 'win',
#   'SantoBlue': 'resigned',
#   'black': 'Hikaru',
#   'white': 'SantoBlue',
#   'whoWon': 'black',
#   'date': '2022.04.27',
#   'time': '16:23:54'},
#  422: {'Hikaru': 'win',
#   'AtabayevSaparmyrat': 'resigned',
#   'black': 'Hikaru',
#   'white': 'AtabayevSaparmyrat',
#   'whoWon': 'black',
#   'date': '2022.04.27',
#   'time': '16:27:21'},
#  423: {'Hikaru': 'win',
#   'mbojan': 'resigned',
#   'white': 'Hikaru',
#   'black': 'mbojan',
#   'whoWon': 'white',
#   'date': '2022.04.27',
#   'time': '16:32:17'},
#  424: {'Hikaru': 'checkmated',
#   'vlad_Sid': 'win',
#   'white': 'Hikaru',
#   'black': 'vlad_Sid',
#   'whoWon': 'black',
#   'date': '2022.04.27',
#   'time': '16:36:21'},
#  425: {'Hikaru': 'win',
#   'GAZZAN_3000': 'checkmated',
#   'black': 'Hikaru',
#   'white': 'GAZZAN_3000',
#   'whoWon': 'black',
#   'date': '2022.04.27',
#   'time': '16:40:31'},
#  426: {'Hikaru': 'win',
#   'AlexPapasimakopoulos': 'resigned',
#   'white': 'Hikaru',
#   'black': 'AlexPapasimakopoulos',
#   'whoWon': 'white',
#   'date': '2022.04.27',
#   'time': '16:45:32'},
#  427: {'Hikaru': 'win',
#   'SantoBlue': 'resigned',
#   'white': 'Hikaru',
#   'black': 'SantoBlue',
#   'whoWon': 'white',
#   'date': '2022.04.27',
#   'time': '16:49:23'},
#  428: {'Hikaru': 'win',
#   'Hakob-Hakobyan-Arm': 'checkmated',
#   'black': 'Hikaru',
#   'white': 'Hakob-Hakobyan-Arm',
#   'whoWon': 'black',
#   'date': '2022.04.27',
#   'time': '16:53:48'},
#  429: {'Hikaru': 'win',
#   'AlexPapasimakopoulos': 'resigned',
#   'black': 'Hikaru',
#   'white': 'AlexPapasimakopoulos',
#   'whoWon': 'black',
#   'date': '2022.04.27',
#   'time': '16:58:33'},
#  430: {'Hikaru': 'win',
#   'David_Arutinian': 'timeout',
#   'black': 'Hikaru',
#   'white': 'David_Arutinian',
#   'whoWon': 'black',
#   'date': '2022.04.27',
#   'time': '17:04:00'},
#  431: {'Hikaru': 'win',
#   'AlexPapasimakopoulos': 'resigned',
#   'white': 'Hikaru',
#   'black': 'AlexPapasimakopoulos',
#   'whoWon': 'white',
#   'date': '2022.04.27',
#   'time': '17:06:56'},
#  432: {'Hikaru': 'resigned',
#   'Twitch_ElhamBlitz05': 'win',
#   'white': 'Hikaru',
#   'black': 'Twitch_ElhamBlitz05',
#   'whoWon': 'black',
#   'date': '2022.04.27',
#   'time': '17:12:57'},
#  433: {'Hikaru': 'win',
#   'AlexPapasimakopoulos': 'resigned',
#   'black': 'Hikaru',
#   'white': 'AlexPapasimakopoulos',
#   'whoWon': 'black',
#   'date': '2022.04.27',
#   'time': '17:18:24'},
#  434: {'Hikaru': 'repetition',
#   'MITerryble': 'repetition',
#   'white': 'Hikaru',
#   'black': 'MITerryble',
#   'whoWon': 'draw',
#   'date': '2022.04.27',
#   'time': '17:24:10'},
#  435: {'Hikaru': 'win',
#   'AlexPapasimakopoulos': 'resigned',
#   'white': 'Hikaru',
#   'black': 'AlexPapasimakopoulos',
#   'whoWon': 'white',
#   'date': '2022.04.27',
#   'time': '17:27:45'},
#  436: {'Hikaru': 'win',
#   'David_Arutinian': 'checkmated',
#   'white': 'Hikaru',
#   'black': 'David_Arutinian',
#   'whoWon': 'white',
#   'date': '2022.04.27',
#   'time': '17:32:35'},
#  437: {'Hikaru': 'win',
#   'Kaori98': 'resigned',
#   'black': 'Hikaru',
#   'white': 'Kaori98',
#   'whoWon': 'black',
#   'date': '2022.04.27',
#   'time': '17:34:09'},
#  438: {'Hikaru': 'win',
#   'wonderfultime': 'resigned',
#   'white': 'Hikaru',
#   'black': 'wonderfultime',
#   'whoWon': 'white',
#   'date': '2022.04.27',
#   'time': '17:39:45'},
#  439: {'Hikaru': 'win',
#   'Twitch_ElhamBlitz05': 'timeout',
#   'black': 'Hikaru',
#   'white': 'Twitch_ElhamBlitz05',
#   'whoWon': 'black',
#   'date': '2022.04.27',
#   'time': '17:45:06'},
#  440: {'Hikaru': 'resigned',
#   'Oleksandr_Bortnyk': 'win',
#   'white': 'Hikaru',
#   'black': 'Oleksandr_Bortnyk',
#   'whoWon': 'black',
#   'date': '2022.04.27',
#   'time': '17:48:23'},
#  441: {'Hikaru': 'insufficient',
#   'AlexPapasimakopoulos': 'insufficient',
#   'black': 'Hikaru',
#   'white': 'AlexPapasimakopoulos',
#   'date': '2022.04.27',
#   'time': '17:54:20'},
#  442: {'Hikaru': 'win',
#   'Zhigalko_Sergei': 'resigned',
#   'white': 'Hikaru',
#   'black': 'Zhigalko_Sergei',
#   'whoWon': 'white',
#   'date': '2022.04.27',
#   'time': '17:59:00'},
#  443: {'Hikaru': 'win',
#   'KeshavGupta1': 'checkmated',
#   'white': 'Hikaru',
#   'black': 'KeshavGupta1',
#   'whoWon': 'white',
#   'date': '2022.04.27',
#   'time': '18:17:09'},
#  444: {'Hikaru': 'win',
#   'KeshavGupta1': 'checkmated',
#   'black': 'Hikaru',
#   'white': 'KeshavGupta1',
#   'whoWon': 'black',
#   'date': '2022.04.27',
#   'time': '18:20:13'},
#  445: {'Hikaru': 'win',
#   'emiliochess': 'resigned',
#   'white': 'Hikaru',
#   'black': 'emiliochess',
#   'whoWon': 'white',
#   'date': '2022.04.27',
#   'time': '18:31:37'},
#  446: {'Hikaru': 'win',
#   'emiliochess': 'resigned',
#   'black': 'Hikaru',
#   'white': 'emiliochess',
#   'whoWon': 'black',
#   'date': '2022.04.27',
#   'time': '18:34:00'},
#  447: {'Hikaru': 'win',
#   'MITerryble': 'resigned',
#   'white': 'Hikaru',
#   'black': 'MITerryble',
#   'whoWon': 'white',
#   'date': '2022.04.27',
#   'time': '18:55:24'},
#  448: {'Hikaru': 'win',
#   'MITerryble': 'timeout',
#   'black': 'Hikaru',
#   'white': 'MITerryble',
#   'whoWon': 'black',
#   'date': '2022.04.27',
#   'time': '19:01:55'},
#  449: {'Hikaru': 'checkmated',
#   'Oleksandr_Bortnyk': 'win',
#   'white': 'Hikaru',
#   'black': 'Oleksandr_Bortnyk',
#   'whoWon': 'black',
#   'date': '2022.04.27',
#   'time': '19:33:05'},
#  450: {'Hikaru': 'timeout',
#   'Oleksandr_Bortnyk': 'win',
#   'black': 'Hikaru',
#   'white': 'Oleksandr_Bortnyk',
#   'whoWon': 'white',
#   'date': '2022.04.27',
#   'time': '19:39:18'},
#  451: {'Hikaru': 'win',
#   'Oleksandr_Bortnyk': 'resigned',
#   'white': 'Hikaru',
#   'black': 'Oleksandr_Bortnyk',
#   'whoWon': 'white',
#   'date': '2022.04.27',
#   'time': '19:44:10'},
#  452: {'Hikaru': 'win',
#   'Oleksandr_Bortnyk': 'timeout',
#   'black': 'Hikaru',
#   'white': 'Oleksandr_Bortnyk',
#   'whoWon': 'black',
#   'date': '2022.04.27',
#   'time': '19:50:06'},
#  453: {'Hikaru': 'win',
#   'Oleksandr_Bortnyk': 'timeout',
#   'white': 'Hikaru',
#   'black': 'Oleksandr_Bortnyk',
#   'whoWon': 'white',
#   'date': '2022.04.27',
#   'time': '19:54:46'},
#  454: {'Hikaru': 'win',
#   'NikoTheodorou': 'resigned',
#   'white': 'Hikaru',
#   'black': 'NikoTheodorou',
#   'whoWon': 'white',
#   'date': '2022.04.27',
#   'time': '20:58:42'},
#  455: {'Hikaru': 'win',
#   'NikoTheodorou': 'resigned',
#   'black': 'Hikaru',
#   'white': 'NikoTheodorou',
#   'whoWon': 'black',
#   'date': '2022.04.27',
#   'time': '21:03:54'},
#  456: {'Hikaru': 'win',
#   'NikoTheodorou': 'resigned',
#   'white': 'Hikaru',
#   'black': 'NikoTheodorou',
#   'whoWon': 'white',
#   'date': '2022.04.27',
#   'time': '21:06:55'}}

# %%
# Использовать OAuth для аутентификации пользователей не через мою базу данных а позволить им зайти по Facebook или Instagram или VK логину.
